# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("Merged_Cleansed\BackTest_Fast.csv")
SPY = pd.read_csv("Merged_Cleansed\SPY_Train.csv")

# %%
df = df[df['Price'] >= 5]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
df.head(3)
# Out:
#          Date  PERMNO TICKER   Price    Return  Shares Outstanding  \
# 0  1995-02-01   10057    AMT  15.625 -0.072000                6300
# 2  1995-02-01   10145    ALD  35.750  0.064895              282987
# 3  1995-02-01   10147    EMC  18.625 -0.080537              195875
#
#    Turnover Rank  Dollar Turnover Rank  Current Ratio Rank  Cash Ratio Rank  \
# 0              1                     2                   3                2
# 2              6                     4                   7                6
# 3              1                     1                   2                2
#
#    Quick Ratio Rank  Revenue Growth Rank  COGS Growth Rank  \
# 0                 3                    8                 9
# 2                 8                    8                 8
# 3                 2                    1                 1
#
#    Operating Income Growth Rank  Net Income Growth Rank  \
# 0                            10                       7
# 2                             8                       6
# 3                             2                       3
#
#    EPS Basic Growth Rank  Net Operating Cash Flow Growth Rank
# 0                      9                                    1
# 2                      6                                    3
# 3                      3                                    1

# %%
SPY.head(3)
# Out:
#          Date    Return
# 0  1995-01-01  0.012817
# 1  1995-02-01  0.024591
# 2  1995-03-01  0.032419

# %%
df.groupby('Date').describe()
# Out:
#             PERMNO                                                          \
#              count          mean           std      min       25%      50%
# Date
# 1995-02-01   790.0  52021.525316  22970.142619  10057.0  30563.75  54507.0
# 1995-03-01   821.0  52472.131547  22997.238720  10057.0  31464.00  55976.0
# 1995-04-01   821.0  52366.303289  22990.669864  10057.0  31464.00  55597.0
# 1995-05-01   825.0  52344.419394  22974.753068  10057.0  31464.00  55213.0
# 1995-06-01   871.0  52967.664753  23234.007743  10057.0  32419.00  57066.0
# ...            ...           ...           ...      ...       ...      ...
# 2015-08-01  1345.0  55324.682528  32136.708318  10051.0  15046.00  64899.0
# 2015-09-01  1345.0  55042.388848  32174.079641  10051.0  15055.00  64311.0
# 2015-10-01  1315.0  54951.411407  32078.784390  10051.0  15106.50  63830.0
# 2015-11-01  1320.0  54898.093182  32110.558667  10051.0  15065.50  64012.0
# 2015-12-01  1338.0  54214.544096  32233.041516  10051.0  15125.50  61775.0
#
#                                 Price                                        \
#                  75%      max   count       mean        std   min       25%
# Date
# 1995-02-01  75481.75  92655.0   790.0  27.146084  17.803424  5.00  15.40625
# 1995-03-01  75625.00  92655.0   821.0  27.612363  18.517895  5.00  15.25000
# 1995-04-01  75602.00  92655.0   821.0  28.320646  18.915912  5.00  15.62500
# 1995-05-01  75602.00  92655.0   825.0  28.784773  18.985401  5.00  16.12500
# 1995-06-01  75884.50  92655.0   871.0  29.142939  19.436188  5.00  15.75000
# ...              ...      ...     ...        ...        ...   ...       ...
# 2015-08-01  86218.00  93427.0  1345.0  49.139407  53.399632  5.03  18.56000
# 2015-09-01  86106.00  93427.0  1345.0  46.405922  50.982006  5.01  17.63000
# 2015-10-01  86006.00  93427.0  1315.0  44.618030  49.626053  5.11  16.60500
# 2015-11-01  85961.00  93427.0  1320.0  47.277348  51.494996  5.03  17.59250
# 2015-12-01  85925.75  93427.0  1338.0  46.806045  51.018063  5.06  17.20000
#
#                                         Return                                \
#                50%      75%        max   count      mean       std       min
# Date
# 1995-02-01  23.500  34.1875  240.75000   790.0  0.037334  0.073803 -0.335106
# 1995-03-01  24.125  35.2500  253.25000   821.0  0.033975  0.083175 -0.274809
# 1995-04-01  24.875  36.0000  257.00000   821.0  0.023100  0.089547 -0.333333
# 1995-05-01  24.875  36.6250  257.75000   825.0  0.020467  0.073053 -0.208696
# 1995-06-01  25.375  37.1875  264.75000   871.0  0.030842  0.085704 -0.244898
# ...            ...      ...        ...     ...       ...       ...       ...
# 2015-08-01  35.780  61.7100  742.22998  1345.0 -0.052258  0.090101 -0.675367
# 2015-09-01  33.310  58.0800  715.98999  1345.0 -0.062151  0.103415 -0.645542
# 2015-10-01  31.940  56.2200  723.83002  1315.0  0.070949  0.112892 -0.589187
# 2015-11-01  33.685  59.5725  784.40997  1320.0 -0.000342  0.104382 -0.545687
# 2015-12-01  32.650  58.5950  783.77002  1338.0 -0.048205  0.096445 -0.645474
#
#                                                    Shares Outstanding  \
#                  25%       50%       75%       max              count
# Date
# 1995-02-01  0.000000  0.034965  0.074954  0.375000              790.0
# 1995-03-01 -0.013928  0.030303  0.076768  0.421053              821.0
# 1995-04-01 -0.025641  0.019048  0.066667  0.549455              821.0
# 1995-05-01 -0.020000  0.016627  0.057432  0.529474              825.0
# 1995-06-01 -0.018863  0.019685  0.071715  0.634328              871.0
# ...              ...       ...       ...       ...                ...
# 2015-08-01 -0.094590 -0.051484 -0.011216  0.402141             1345.0
# 2015-09-01 -0.113739 -0.050934  0.000000  0.348011             1345.0
# 2015-10-01  0.017511  0.072633  0.127016  0.599315             1315.0
# 2015-11-01 -0.046017  0.002762  0.043754  0.883459             1320.0
# 2015-12-01 -0.095094 -0.041211  0.006874  0.691379             1338.0
#
#                                                                                \
#                      mean            std     min      25%      50%        75%
# Date
# 1995-02-01   77255.237975  152220.433588  2090.0  14733.0  33556.5   76654.50
# 1995-03-01   76193.975639  150147.450877  2090.0  14769.0  32451.0   75500.00
# 1995-04-01   76942.857491  152579.835688  1922.0  14867.0  32105.0   76295.00
# 1995-05-01   75621.207273  145957.315222  1922.0  14652.0  32016.0   74570.00
# 1995-06-01   75376.117107  144609.523025  1289.0  14253.5  31047.0   73477.50
# ...                   ...            ...     ...      ...      ...        ...
# 2015-08-01  207129.077323  451586.966782   450.0  37885.0  77286.0  179962.00
# 2015-09-01  209242.008178  462974.960374   450.0  37880.0  76603.0  179962.00
# 2015-10-01  207466.632700  455226.294869  1600.0  38112.5  76603.0  179502.00
# 2015-11-01  206388.491667  454058.140364  1600.0  37750.5  75720.0  178057.25
# 2015-12-01  202567.637519  448921.257580  1600.0  37713.5  75472.0  175915.00
#
#                       Turnover Rank                                          \
#                   max         count      mean       std  min  25%  50%  75%
# Date
# 1995-02-01  2298224.0         790.0  5.429114  2.842180  1.0  3.0  5.0  8.0
# 1995-03-01  2298224.0         821.0  5.410475  2.842764  1.0  3.0  5.0  8.0
# 1995-04-01  2297579.0         821.0  5.415347  2.854899  1.0  3.0  5.0  8.0
# 1995-05-01  2297579.0         825.0  5.401212  2.847712  1.0  3.0  5.0  8.0
# 1995-06-01  2297579.0         871.0  5.398393  2.846809  1.0  3.0  5.0  8.0
# ...               ...           ...       ...       ...  ...  ...  ...  ...
# 2015-08-01  6157670.0        1345.0  5.432714  2.821337  1.0  3.0  5.0  8.0
# 2015-09-01  6167348.0        1345.0  5.415613  2.821140  1.0  3.0  5.0  8.0
# 2015-10-01  6167348.0        1315.0  5.422814  2.767901  1.0  3.0  5.0  8.0
# 2015-11-01  6167348.0        1320.0  5.402273  2.802765  1.0  3.0  5.0  8.0
# 2015-12-01  6173503.0        1338.0  5.394619  2.806878  1.0  3.0  5.0  8.0
#
#                  Dollar Turnover Rank                                          \
#              max                count      mean       std  min  25%  50%  75%
# Date
# 1995-02-01  10.0                790.0  5.324051  2.804813  1.0  3.0  5.0  8.0
# 1995-03-01  10.0                821.0  5.341048  2.808634  1.0  3.0  5.0  8.0
# 1995-04-01  10.0                821.0  5.330085  2.798420  1.0  3.0  5.0  8.0
# 1995-05-01  10.0                825.0  5.333333  2.798520  1.0  3.0  5.0  8.0
# 1995-06-01  10.0                871.0  5.344432  2.805305  1.0  3.0  5.0  8.0
# ...          ...                  ...       ...       ...  ...  ...  ...  ...
# 2015-08-01  10.0               1345.0  5.193309  2.733138  1.0  3.0  5.0  8.0
# 2015-09-01  10.0               1345.0  5.180669  2.727328  1.0  3.0  5.0  7.0
# 2015-10-01  10.0               1315.0  5.123194  2.710828  1.0  3.0  5.0  7.0
# 2015-11-01  10.0               1320.0  5.143182  2.718808  1.0  3.0  5.0  7.0
# 2015-12-01  10.0               1338.0  5.124066  2.705628  1.0  3.0  5.0  7.0
#
#                  Current Ratio Rank                                          \
#              max              count      mean       std  min  25%  50%  75%
# Date
# 1995-02-01  10.0              790.0  5.458228  2.873797  1.0  3.0  5.0  8.0
# 1995-03-01  10.0              821.0  5.475030  2.869252  1.0  3.0  5.0  8.0
# 1995-04-01  10.0              821.0  5.493301  2.865100  1.0  3.0  6.0  8.0
# 1995-05-01  10.0              825.0  5.494545  2.861323  1.0  3.0  6.0  8.0
# 1995-06-01  10.0              871.0  5.483352  2.857438  1.0  3.0  5.0  8.0
# ...          ...                ...       ...       ...  ...  ...  ...  ...
# 2015-08-01  10.0             1345.0  5.511524  2.874621  1.0  3.0  6.0  8.0
# 2015-09-01  10.0             1345.0  5.507063  2.868935  1.0  3.0  6.0  8.0
# 2015-10-01  10.0             1315.0  5.495817  2.858767  1.0  3.0  5.0  8.0
# 2015-11-01  10.0             1320.0  5.504545  2.867291  1.0  3.0  5.0  8.0
# 2015-12-01  10.0             1338.0  5.488042  2.856622  1.0  3.0  5.0  8.0
#
#                  Cash Ratio Rank                                          \
#              max           count      mean       std  min  25%  50%  75%
# Date
# 1995-02-01  10.0           790.0  5.477215  2.875774  1.0  3.0  5.0  8.0
# 1995-03-01  10.0           821.0  5.476248  2.874782  1.0  3.0  5.0  8.0
# 1995-04-01  10.0           821.0  5.488429  2.880790  1.0  3.0  5.0  8.0
# 1995-05-01  10.0           825.0  5.498182  2.867259  1.0  3.0  5.0  8.0
# 1995-06-01  10.0           871.0  5.497130  2.876329  1.0  3.0  6.0  8.0
# ...          ...             ...       ...       ...  ...  ...  ...  ...
# 2015-08-01  10.0          1345.0  5.536803  2.849711  1.0  3.0  6.0  8.0
# 2015-09-01  10.0          1345.0  5.533086  2.854713  1.0  3.0  6.0  8.0
# 2015-10-01  10.0          1315.0  5.553612  2.853203  1.0  3.0  6.0  8.0
# 2015-11-01  10.0          1320.0  5.546970  2.849403  1.0  3.0  6.0  8.0
# 2015-12-01  10.0          1338.0  5.541854  2.863924  1.0  3.0  6.0  8.0
#
#                  Quick Ratio Rank                                          \
#              max            count      mean       std  min  25%  50%  75%
# Date
# 1995-02-01  10.0            790.0  5.460759  2.878240  1.0  3.0  5.0  8.0
# 1995-03-01  10.0            821.0  5.478685  2.875650  1.0  3.0  5.0  8.0
# 1995-04-01  10.0            821.0  5.485993  2.870177  1.0  3.0  5.0  8.0
# 1995-05-01  10.0            825.0  5.499394  2.867683  1.0  3.0  6.0  8.0
# 1995-06-01  10.0            871.0  5.484501  2.871889  1.0  3.0  5.0  8.0
# ...          ...              ...       ...       ...  ...  ...  ...  ...
# 2015-08-01  10.0           1345.0  5.514498  2.863196  1.0  3.0  6.0  8.0
# 2015-09-01  10.0           1345.0  5.512268  2.861907  1.0  3.0  6.0  8.0
# 2015-10-01  10.0           1315.0  5.516350  2.856060  1.0  3.0  6.0  8.0
# 2015-11-01  10.0           1320.0  5.517424  2.864067  1.0  3.0  6.0  8.0
# 2015-12-01  10.0           1338.0  5.505232  2.866836  1.0  3.0  5.0  8.0
#
#                  Revenue Growth Rank                                          \
#              max               count      mean       std  min  25%  50%  75%
# Date
# 1995-02-01  10.0               790.0  5.481013  2.857675  1.0  3.0  5.0  8.0
# 1995-03-01  10.0               821.0  5.477467  2.870547  1.0  3.0  5.0  8.0
# 1995-04-01  10.0               821.0  5.472594  2.870929  1.0  3.0  5.0  8.0
# 1995-05-01  10.0               825.0  5.487273  2.873151  1.0  3.0  5.0  8.0
# 1995-06-01  10.0               871.0  5.442021  2.868942  1.0  3.0  5.0  8.0
# ...          ...                 ...       ...       ...  ...  ...  ...  ...
# 2015-08-01  10.0              1345.0  5.415613  2.844516  1.0  3.0  5.0  8.0
# 2015-09-01  10.0              1345.0  5.478067  2.852213  1.0  3.0  5.0  8.0
# 2015-10-01  10.0              1315.0  5.460837  2.842482  1.0  3.0  5.0  8.0
# 2015-11-01  10.0              1320.0  5.464394  2.853290  1.0  3.0  5.0  8.0
# 2015-12-01  10.0              1338.0  5.446188  2.834585  1.0  3.0  5.0  8.0
#
#                  COGS Growth Rank                                          \
#              max            count      mean       std  min  25%  50%  75%
# Date
# 1995-02-01  10.0            790.0  5.489873  2.866134  1.0  3.0  5.5  8.0
# 1995-03-01  10.0            821.0  5.465286  2.865323  1.0  3.0  5.0  8.0
# 1995-04-01  10.0            821.0  5.459196  2.868645  1.0  3.0  5.0  8.0
# 1995-05-01  10.0            825.0  5.472727  2.873472  1.0  3.0  5.0  8.0
# 1995-06-01  10.0            871.0  5.450057  2.867892  1.0  3.0  5.0  8.0
# ...          ...              ...       ...       ...  ...  ...  ...  ...
# 2015-08-01  10.0           1345.0  5.446097  2.826104  1.0  3.0  5.0  8.0
# 2015-09-01  10.0           1345.0  5.501115  2.853080  1.0  3.0  5.0  8.0
# 2015-10-01  10.0           1315.0  5.478327  2.838383  1.0  3.0  5.0  8.0
# 2015-11-01  10.0           1320.0  5.492424  2.849514  1.0  3.0  5.0  8.0
# 2015-12-01  10.0           1338.0  5.438714  2.832322  1.0  3.0  5.0  8.0
#
#                  Operating Income Growth Rank                                \
#              max                        count      mean       std  min  25%
# Date
# 1995-02-01  10.0                        790.0  5.440506  2.850901  1.0  3.0
# 1995-03-01  10.0                        821.0  5.478685  2.861195  1.0  3.0
# 1995-04-01  10.0                        821.0  5.455542  2.866039  1.0  3.0
# 1995-05-01  10.0                        825.0  5.486061  2.862990  1.0  3.0
# 1995-06-01  10.0                        871.0  5.456946  2.863190  1.0  3.0
# ...          ...                          ...       ...       ...  ...  ...
# 2015-08-01  10.0                       1345.0  5.452788  2.837259  1.0  3.0
# 2015-09-01  10.0                       1345.0  5.430483  2.837849  1.0  3.0
# 2015-10-01  10.0                       1315.0  5.405323  2.828288  1.0  3.0
# 2015-11-01  10.0                       1320.0  5.403030  2.827836  1.0  3.0
# 2015-12-01  10.0                       1338.0  5.406577  2.831443  1.0  3.0
#
#                            Net Income Growth Rank                           \
#             50%  75%   max                  count      mean       std  min
# Date
# 1995-02-01  5.0  8.0  10.0                  790.0  5.456962  2.842738  1.0
# 1995-03-01  5.0  8.0  10.0                  821.0  5.456760  2.849843  1.0
# 1995-04-01  5.0  8.0  10.0                  821.0  5.472594  2.859864  1.0
# 1995-05-01  5.0  8.0  10.0                  825.0  5.496970  2.850277  1.0
# 1995-06-01  6.0  8.0  10.0                  871.0  5.462687  2.852411  1.0
# ...         ...  ...   ...                    ...       ...       ...  ...
# 2015-08-01  5.0  8.0  10.0                 1345.0  5.457993  2.858243  1.0
# 2015-09-01  5.0  8.0  10.0                 1345.0  5.451301  2.834873  1.0
# 2015-10-01  5.0  8.0  10.0                 1315.0  5.453992  2.823845  1.0
# 2015-11-01  5.0  8.0  10.0                 1320.0  5.446212  2.822548  1.0
# 2015-12-01  5.0  8.0  10.0                 1338.0  5.448430  2.830666  1.0
#
#                                 EPS Basic Growth Rank                      \
#             25%  50%  75%   max                 count      mean       std
# Date
# 1995-02-01  3.0  5.0  8.0  10.0                 790.0  5.468354  2.839766
# 1995-03-01  3.0  5.0  8.0  10.0                 821.0  5.445798  2.851366
# 1995-04-01  3.0  5.0  8.0  10.0                 821.0  5.490865  2.861260
# 1995-05-01  3.0  6.0  8.0  10.0                 825.0  5.503030  2.851554
# 1995-06-01  3.0  5.0  8.0  10.0                 871.0  5.450057  2.850605
# ...         ...  ...  ...   ...                   ...       ...       ...
# 2015-08-01  3.0  5.0  8.0  10.0                1345.0  5.454275  2.858186
# 2015-09-01  3.0  5.0  8.0  10.0                1345.0  5.455762  2.828114
# 2015-10-01  3.0  5.0  8.0  10.0                1315.0  5.449430  2.821610
# 2015-11-01  3.0  5.0  8.0  10.0                1320.0  5.449242  2.816958
# 2015-12-01  3.0  5.0  8.0  10.0                1338.0  5.455157  2.827873
#
#                                      Net Operating Cash Flow Growth Rank  \
#             min  25%  50%  75%   max                               count
# Date
# 1995-02-01  1.0  3.0  5.0  8.0  10.0                               790.0
# 1995-03-01  1.0  3.0  5.0  8.0  10.0                               821.0
# 1995-04-01  1.0  3.0  6.0  8.0  10.0                               821.0
# 1995-05-01  1.0  3.0  6.0  8.0  10.0                               825.0
# 1995-06-01  1.0  3.0  5.0  8.0  10.0                               871.0
# ...         ...  ...  ...  ...   ...                                 ...
# 2015-08-01  1.0  3.0  5.0  8.0  10.0                              1345.0
# 2015-09-01  1.0  3.0  5.0  8.0  10.0                              1345.0
# 2015-10-01  1.0  3.0  5.0  8.0  10.0                              1315.0
# 2015-11-01  1.0  3.0  5.0  8.0  10.0                              1320.0
# 2015-12-01  1.0  3.0  5.0  8.0  10.0                              1338.0
#
#
#                 mean       std  min  25%  50%  75%   max
# Date
# 1995-02-01  5.455696  2.872877  1.0  3.0  5.0  8.0  10.0
# 1995-03-01  5.425091  2.867957  1.0  3.0  5.0  8.0  10.0
# 1995-04-01  5.434836  2.860957  1.0  3.0  5.0  8.0  10.0
# 1995-05-01  5.450909  2.861754  1.0  3.0  5.0  8.0  10.0
# 1995-06-01  5.474168  2.868210  1.0  3.0  5.0  8.0  10.0
# ...              ...       ...  ...  ...  ...  ...   ...
# 2015-08-01  5.468401  2.872399  1.0  3.0  5.0  8.0  10.0
# 2015-09-01  5.431970  2.861384  1.0  3.0  5.0  8.0  10.0
# 2015-10-01  5.434981  2.865476  1.0  3.0  5.0  8.0  10.0
# 2015-11-01  5.456061  2.871186  1.0  3.0  5.0  8.0  10.0
# 2015-12-01  5.406577  2.842779  1.0  3.0  5.0  8.0  10.0
#
# [251 rows x 120 columns]

# %% [markdown]
# # Rank for factor

# %% [markdown]
# ## Date Processing

# %%
# Transform Date into datetime type
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

SPY['Date'] = pd.to_datetime(SPY['Date'])
SPY.set_index('Date', inplace=True)

# %%
# Construct Date List
Date = []
for i in range(1995, 2016):
    for j in range(1, 13):
        date = str(i) + '-' + str(j)
        Date.append(date)
        
Date = Date[1:]

# %% [markdown]
# ## Define Rank Function and Use it to rank for each factor

# %%
def percentile_to_score(value):
    if value >= 0.9: value = 1
    elif value >= 0.8: value = 2
    elif value >= 0.7: value = 3
    elif value >= 0.6: value = 4
    elif value >= 0.5: value = 5
    elif value >= 0.4: value = 6
    elif value >= 0.3: value = 7
    elif value >= 0.2: value = 8
    elif value >= 0.1: value = 9
    elif value >= 0.0: value = 10
    return value 

def Rank(df_, factor, factor_rank, Date):
    df = df_.copy()
        
    # First, we select the first date's dataframe and rank
    dataframe = df[Date[0]].copy()
#     dataframe = dataframe.sort_values(by = [factor], axis = 0, ascending = False)  # Sort by Turnover
#     dataframe[factor_rank] = range(len(dataframe))  
#     dataframe[factor_rank] += 1 
    dataframe[factor_rank] = dataframe[factor].rank(pct=True).apply(lambda x: percentile_to_score(x))
    
    for i in range(1, len(Date)):
        DF = df[Date[i]].copy()  # Divide the big df into small DF by date
#         DF = DF.sort_values(by = [factor], axis = 0, ascending = False)  # Sort by Turnover
#         DF[factor_rank] = range(len(DF))  
#         DF[factor_rank] += 1 
        DF[factor_rank] = DF[factor].rank(pct=True).apply(lambda x: percentile_to_score(x))
        dataframe = pd.concat([dataframe, DF])
    
    return dataframe

# %%
Factor_List = ['Turnover', 'Dollar Turnover', 'Current Ratio', 'Cash Ratio', 'Quick Ratio',
 'Revenue Growth', 'COGS Growth', 'Operating Income Growth', 'Net Income Growth', 'EPS Basic Growth',
 'Net Operating Cash Flow Growth']

Factor_Rank = ['Turnover Rank', 'Dollar Turnover Rank', 'Current Ratio Rank',
 'Cash Ratio Rank', 'Quick Ratio Rank', 'Revenue Growth Rank',
 'COGS Growth Rank', 'Operating Income Growth Rank', 'Net Income Growth Rank',
 'EPS Basic Growth Rank', 'Net Operating Cash Flow Growth Rank']

# %% [markdown]
# # Select Stocks based on Rank

# %%
class Solve():
    def __init__(self, df, SPY, Date, Factor_Rank):
        self.df = df
        self.SPY = SPY
        self.Date = Date
        self.Factor_Rank = Factor_Rank
        
    def Combine_Factors(self):
        self.df['Liquid Ratio Rank'] = (self.df['Cash Ratio Rank'] + self.df['Current Ratio Rank'] + self.df['Quick Ratio Rank']) / 3 
        self.df['Turnover Combine Rank'] = (self.df['Turnover Rank'] + self.df['Dollar Turnover Rank']) / 2
        self.df['Liquidity Combine Rank'] = (self.df['Liquid Ratio Rank'] + self.df['Turnover Combine Rank']) / 2
        self.df['Growth Combine Rank'] = (self.df['Net Operating Cash Flow Growth Rank'] + self.df['EPS Basic Growth Rank'] + 
                                            self.df['Revenue Growth Rank'] + self.df['COGS Growth Rank'] + 
                                            self.df['Operating Income Growth Rank'] + self.df['Net Income Growth Rank']) / 6
        
        self.df['Total Rank'] = (self.df['Liquidity Combine Rank'] + self.df['Growth Combine Rank']) / 2 
                              
    def Get_Returns(self):
        self.df_ = self.df.copy()
        self.Returns1 = {} # Used to store TOP each factor's return for each month
        self.Returns2 = {} # Used to store BOT each factor's return for each month
        self.Excesses1 = {} # Used to store TOP each factor's excess return for each month
        self.Excesses2 = {} # Used to store BOT each factor's excess return for each month
        self.Diffs = {} # Used to store each factor's diff return for each month
        self.Diffs_Excess = {} # Used to store each factor's diff excess return for each month
           
        for factor in self.Factor_Rank:
            Return1 = []  # Used to store TOP return for each month
            Return2 = []  # Used to store BOT return for each month
            Excess1 = []  # Used to store TOP excess return for each month
            Excess2 = []  # Used to store BOT excess return for each month
            Diff = []    # Used to store return of difference between TOP and BOT for each month
            Diff_Excess = []    # Used to store excess return of difference between TOP and BOT for each month
            for date in Date:
                DF = self.df_[date].copy()  # Divide the big df into small DF by date
                N = int(len(DF)/10)   # We decide to long top 10% of universe and short bottom 10%
                DF = DF.sort_values(by = [factor], axis = 0, ascending = True)  # Sort by Turnover
                #profit = ( DF.iloc[:N]['Return'].mean() - DF.iloc[-N:]['Return'].mean() ) / 2 
                profit1 = DF.iloc[:N]['Return'].mean()
                profit2 = DF.iloc[-N:]['Return'].mean()
                diff = profit1 - profit2
                profit_SPY = self.SPY[date]['Return'].values[0]

                Return1.append( profit1 )
                Return2.append( profit2 )
                Excess1.append( profit1 - profit_SPY )
                Excess2.append( profit2 - profit_SPY )
                Diff.append( diff )
                Diff_Excess.append( diff - profit_SPY )

            self.Returns1[factor] = Return1 
            self.Returns2[factor] = Return2 
            self.Excesses1[factor] = Excess1
            self.Excesses2[factor] = Excess2
            self.Diffs[factor] = Diff
            self.Diffs_Excess[factor] = Diff_Excess

    def Return_Summary(self):
        print("Summary for SPY Return:"); print(self.SPY['Return'].describe())
        print("=============++++++++++++++=============")
        
        for key in self.Factor_Rank:
            print("=================" + key + "=================")
            print("Summary for TOP Return:"); print(pd.Series(self.Returns1[key]).describe(), "\n")
            print("Summary for BOT Return:"); print(pd.Series(self.Returns2[key]).describe(), "\n")
            print("Summary for Diff Return:"); print(pd.Series(self.Diffs[key]).describe(), "\n")
            print("Summary for TOP Excess Return:"); print(pd.Series(self.Excesses1[key]).describe(), "\n")
            print("Summary for BOT Excess Return:"); print(pd.Series(self.Excesses2[key]).describe(), "\n")
            print("Summary for Diff Excess Return:"); print(pd.Series(self.Diffs_Excess[key]).describe())
            print("=================++++++++++++++=================")
        
    def T_Test_Return(self):
        from scipy import stats
        print("==============================T Test For Return==============================")
        for factor in self.Factor_Rank:
            print("Result of T Test for " + factor + "(TOP):")
            print(stats.ttest_1samp(self.Returns1[factor], 0))
            print("Result of T Test for " + factor + "(BOT):")
            print(stats.ttest_1samp(self.Returns2[factor], 0))
            print("Result of T Test for " + factor + "(Diff):")
            print(stats.ttest_1samp(self.Diffs[factor], 0))
            print("==============================++++++++++++++==============================")
            
    def T_Test_Excess(self):
        from scipy import stats
        print("==============================T Test For Excess Return==============================")
        for factor in self.Factor_Rank:
            print("Result of T Test for " + factor + "(TOP):")
            print(stats.ttest_1samp(self.Excesses1[factor], 0))
            print("Result of T Test for " + factor + "(BOT):")
            print(stats.ttest_1samp(self.Excesses2[factor], 0))
            print("Result of T Test for " + factor + "(Diff Excess):")
            print(stats.ttest_1samp(self.Diffs_Excess[factor], 0))
            print("==============================++++++++++++++==============================")
            
    def Plot_hist_Return(self):
        plt.figure(figsize=(15,3))
        count = 0
        
        for key in self.Factor_Rank:
            count += 1
            ax = plt.subplot(13,6,count)
            plt.hist(self.Returns1[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of TOP Return from' + key)
            
            count += 1
            ax = plt.subplot(13,6,count)
            plt.hist(self.Excesses1[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of TOP Excess Return from' + key)
            
            count += 1
            ax = plt.subplot(13,6,count)
            plt.hist(self.Returns2[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of BOT Return from' + key)
            
            count += 1
            ax = plt.subplot(13,6,count)
            plt.hist(self.Excesses2[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of BOT Excess Return from' + key)
            
            count += 1
            ax = plt.subplot(13,6,count)
            plt.hist(self.Diffs[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of Diff Return from' + key)
            
            count += 1
            ax = plt.subplot(13,6,count)
            plt.hist(self.Diffs_Excess[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of Diff Excess Return from' + key)


    def Plot_Cum_TOP_Return(self):
        fig1 = plt.figure(figsize = (20, 10))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Returns1[factor])+1).cumprod()-1, label = factor) 
            
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Returns for each Factor (TOP)',fontsize =15)
        
        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 0.9, len(ax1.lines))]
        
        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)
        
    def Plot_Cum_TOP_Excess(self):

        fig1 = plt.figure(figsize = (20, 10))
        ax1 = fig1.add_subplot(111)
        
        #plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black') 

        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Excesses1[factor])+1).cumprod()-1, label = factor) 
 
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Excess Returns for each Factor (TOP)',fontsize =15)

        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 0.9, len(ax1.lines))]

        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)
        
    def Plot_Cum_BOT_Return(self):
        fig1 = plt.figure(figsize = (20, 10))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Returns2[factor])+1).cumprod()-1, label = factor) 
            
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Returns for each Factor (BOT)',fontsize =15)
        
        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 0.9, len(ax1.lines))]
        
        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)
        
    def Plot_Cum_BOT_Excess(self):

        fig1 = plt.figure(figsize = (20, 10))
        ax1 = fig1.add_subplot(111)
        
        #plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black') 

        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Excesses2[factor])+1).cumprod()-1, label = factor) 
 
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Excess Returns for each Factor (BOT)',fontsize =15)

        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 0.9, len(ax1.lines))]

        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)
        
    def Plot_Cum_Diff_Return(self):
        fig1 = plt.figure(figsize = (20, 10))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Diffs[factor])+1).cumprod()-1, label = factor) 
            
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Returns for each Factor (BOT)',fontsize =15)
        
        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 0.9, len(ax1.lines))]
        
        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)
        
    def Plot_Cum_Diff_Excess(self):
        fig1 = plt.figure(figsize = (20, 10))
        ax1 = fig1.add_subplot(111)
        
        #plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Diffs_Excess[factor])+1).cumprod()-1, label = factor) 
            
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Excess Returns for each Factor (BOT)',fontsize =15)
        
        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 0.9, len(ax1.lines))]
        
        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)

# %%
Object = Solve(df, SPY, Date, Factor_Rank)

# %% [markdown]
# ## Calculate Returns and Excess Returns

# %%
Object.Get_Returns()

# %% [markdown]
# ## Give a Summary for all Factors' Return and Excess

# %%
Object.Return_Summary()
# Out:
# Summary for SPY Return:
# count    252.000000
# mean       0.007206
# std        0.046654
# min       -0.167743
# 25%       -0.019238
# 50%        0.012929
# 75%        0.034528
# max        0.157330
# Name: Return, dtype: float64
# =============++++++++++++++=============
# =================Turnover Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.014068
# std        0.070330
# min       -0.260924
# 25%       -0.033439
# 50%        0.013749
# 75%        0.062278
# max        0.246111
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.010762
# std        0.042720
# min       -0.185736
# 25%       -0.011537
# 50%        0.013804
# 75%        0.037454
# max        0.124758
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.003306
# std        0.039516
# min       -0.121048
# 25%       -0.023594
# 50%       -0.001000
# 75%        0.029014
# max        0.127049
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.006884
# std        0.080527
# min       -0.229476
# 25%       -0.048638
# 50%        0.006156
# 75%        0.053603
# max        0.306015
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.003578
# std        0.056090
# min       -0.168029
# 25%       -0.029314
# 50%        0.002377
# 75%        0.035541
# max        0.205697
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.003877
# std        0.062959
# min       -0.184085
# 25%       -0.043224
# 50%       -0.012517
# 75%        0.031707
# max        0.220327
# dtype: float64
# =================++++++++++++++=================
# =================Dollar Turnover Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.011126
# std        0.056668
# min       -0.253093
# 25%       -0.023937
# 50%        0.013855
# 75%        0.051653
# max        0.148626
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.012672
# std        0.051020
# min       -0.241868
# 25%       -0.012223
# 50%        0.018494
# 75%        0.041677
# max        0.190507
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean      -0.001547
# std        0.031093
# min       -0.128256
# 25%       -0.019820
# 50%       -0.000882
# 75%        0.015582
# max        0.092352
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.003942
# std        0.068383
# min       -0.207176
# 25%       -0.037359
# 50%        0.004738
# 75%        0.041913
# max        0.239639
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.005489
# std        0.060596
# min       -0.189932
# 25%       -0.033514
# 50%        0.004791
# 75%        0.037953
# max        0.223041
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.008730
# std        0.059565
# min       -0.199210
# 25%       -0.045221
# 50%       -0.012929
# 75%        0.026625
# max        0.193731
# dtype: float64
# =================++++++++++++++=================
# =================Current Ratio Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.010676
# std        0.054442
# min       -0.209265
# 25%       -0.019881
# 50%        0.015754
# 75%        0.042605
# max        0.187850
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.010427
# std        0.046280
# min       -0.201214
# 25%       -0.014523
# 50%        0.013466
# 75%        0.039569
# max        0.168351
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.000250
# std        0.022324
# min       -0.070559
# 25%       -0.014135
# 50%       -0.000221
# 75%        0.012957
# max        0.065975
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.003493
# std        0.065811
# min       -0.212545
# 25%       -0.042103
# 50%        0.003574
# 75%        0.041171
# max        0.246947
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.003243
# std        0.059061
# min       -0.182287
# 25%       -0.036015
# 50%        0.001485
# 75%        0.035213
# max        0.233795
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.006934
# std        0.052003
# min       -0.171876
# 25%       -0.038800
# 50%       -0.010933
# 75%        0.025019
# max        0.172587
# dtype: float64
# =================++++++++++++++=================
# =================Cash Ratio Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.012114
# std        0.053834
# min       -0.218264
# 25%       -0.018359
# 50%        0.017607
# 75%        0.047873
# max        0.146908
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.011210
# std        0.048160
# min       -0.214939
# 25%       -0.012972
# 50%        0.014037
# 75%        0.042210
# max        0.150747
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.000904
# std        0.024221
# min       -0.063492
# 25%       -0.015555
# 50%        0.000377
# 75%        0.014230
# max        0.087221
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.004930
# std        0.066881
# min       -0.181084
# 25%       -0.038820
# 50%        0.005505
# 75%        0.042366
# max        0.246825
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.004026
# std        0.059692
# min       -0.169711
# 25%       -0.033287
# 50%        0.003199
# 75%        0.037841
# max        0.238084
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.006279
# std        0.055705
# min       -0.178534
# 25%       -0.038010
# 50%       -0.012001
# 75%        0.023383
# max        0.218196
# dtype: float64
# =================++++++++++++++=================
# =================Quick Ratio Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.011494
# std        0.053648
# min       -0.193571
# 25%       -0.022575
# 50%        0.015284
# 75%        0.046955
# max        0.155936
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.010473
# std        0.047217
# min       -0.203490
# 25%       -0.013735
# 50%        0.011431
# 75%        0.041858
# max        0.166804
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.001022
# std        0.025340
# min       -0.058715
# 25%       -0.015831
# 50%        0.001015
# 75%        0.014922
# max        0.119306
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.004310
# std        0.066216
# min       -0.204531
# 25%       -0.042990
# 50%        0.000824
# 75%        0.041359
# max        0.243273
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.003289
# std        0.059998
# min       -0.201094
# 25%       -0.030810
# 50%       -0.000811
# 75%        0.038575
# max        0.238608
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.006162
# std        0.054437
# min       -0.175196
# 25%       -0.039353
# 50%       -0.010602
# 75%        0.025788
# max        0.184579
# dtype: float64
# =================++++++++++++++=================
# =================Revenue Growth Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.012685
# std        0.051715
# min       -0.230139
# 25%       -0.010876
# 50%        0.012392
# 75%        0.043560
# max        0.180266
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.009043
# std        0.050625
# min       -0.207703
# 25%       -0.019707
# 50%        0.013337
# 75%        0.041899
# max        0.155631
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.003643
# std        0.022438
# min       -0.117444
# 25%       -0.007497
# 50%        0.002675
# 75%        0.014808
# max        0.065883
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.005502
# std        0.063391
# min       -0.197875
# 25%       -0.036204
# 50%        0.006123
# 75%        0.038517
# max        0.267602
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.001859
# std        0.061936
# min       -0.202593
# 25%       -0.040593
# 50%       -0.000261
# 75%        0.036856
# max        0.218457
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.003541
# std        0.052531
# min       -0.199360
# 25%       -0.035828
# 50%       -0.007437
# 75%        0.024348
# max        0.155159
# dtype: float64
# =================++++++++++++++=================
# =================COGS Growth Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.012046
# std        0.052252
# min       -0.202262
# 25%       -0.016343
# 50%        0.013094
# 75%        0.046433
# max        0.178140
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.010440
# std        0.048721
# min       -0.194026
# 25%       -0.015523
# 50%        0.015510
# 75%        0.043505
# max        0.145299
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.001606
# std        0.018676
# min       -0.075636
# 25%       -0.011427
# 50%        0.000959
# 75%        0.012854
# max        0.049764
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.004863
# std        0.064493
# min       -0.198388
# 25%       -0.037730
# 50%        0.000723
# 75%        0.037286
# max        0.257117
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.003256
# std        0.061019
# min       -0.178520
# 25%       -0.036446
# 50%        0.002643
# 75%        0.038256
# max        0.211507
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.005577
# std        0.051121
# min       -0.161486
# 25%       -0.034712
# 50%       -0.011515
# 75%        0.020888
# max        0.176369
# dtype: float64
# =================++++++++++++++=================
# =================Operating Income Growth Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.014165
# std        0.053530
# min       -0.266076
# 25%       -0.014316
# 50%        0.017867
# 75%        0.046563
# max        0.184302
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.009467
# std        0.056347
# min       -0.212137
# 25%       -0.020269
# 50%        0.012155
# 75%        0.041966
# max        0.231428
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.004698
# std        0.020992
# min       -0.071567
# 25%       -0.005955
# 50%        0.005566
# 75%        0.016153
# max        0.072322
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.006981
# std        0.063990
# min       -0.187385
# 25%       -0.035675
# 50%        0.007428
# 75%        0.041629
# max        0.271639
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.002283
# std        0.065608
# min       -0.201453
# 25%       -0.040868
# 50%        0.002166
# 75%        0.037943
# max        0.244485
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.002486
# std        0.052208
# min       -0.220367
# 25%       -0.033902
# 50%       -0.004039
# 75%        0.026966
# max        0.177060
# dtype: float64
# =================++++++++++++++=================
# =================Net Income Growth Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.012691
# std        0.053506
# min       -0.252332
# 25%       -0.015124
# 50%        0.015817
# 75%        0.044185
# max        0.212634
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.012590
# std        0.058304
# min       -0.257895
# 25%       -0.017761
# 50%        0.016613
# 75%        0.047590
# max        0.260374
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.000101
# std        0.016592
# min       -0.047740
# 25%       -0.011156
# 50%        0.000397
# 75%        0.012467
# max        0.052476
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.005507
# std        0.063562
# min       -0.192645
# 25%       -0.035369
# 50%        0.005780
# 75%        0.039522
# max        0.263898
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.005406
# std        0.066663
# min       -0.188099
# 25%       -0.037215
# 50%        0.004743
# 75%        0.043887
# max        0.252061
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.007082
# std        0.050923
# min       -0.205070
# 25%       -0.037384
# 50%       -0.009166
# 75%        0.021670
# max        0.166354
# dtype: float64
# =================++++++++++++++=================
# =================EPS Basic Growth Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.013193
# std        0.053385
# min       -0.253658
# 25%       -0.014213
# 50%        0.018112
# 75%        0.045322
# max        0.204754
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.012243
# std        0.058685
# min       -0.261088
# 25%       -0.018512
# 50%        0.017129
# 75%        0.046921
# max        0.253773
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.000950
# std        0.016079
# min       -0.049019
# 25%       -0.009272
# 50%        0.000089
# 75%        0.011656
# max        0.057971
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.006009
# std        0.063569
# min       -0.186197
# 25%       -0.033061
# 50%        0.006355
# 75%        0.041932
# max        0.266465
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.005059
# std        0.066683
# min       -0.169884
# 25%       -0.035970
# 50%        0.003999
# 75%        0.043357
# max        0.251219
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.006234
# std        0.051304
# min       -0.206349
# 25%       -0.035360
# 50%       -0.007779
# 75%        0.023253
# max        0.167266
# dtype: float64
# =================++++++++++++++=================
# =================Net Operating Cash Flow Growth Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.013131
# std        0.053181
# min       -0.237377
# 25%       -0.015182
# 50%        0.017402
# 75%        0.044326
# max        0.209354
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.011197
# std        0.056979
# min       -0.255220
# 25%       -0.018111
# 50%        0.014044
# 75%        0.045906
# max        0.224077
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.001934
# std        0.015422
# min       -0.053557
# 25%       -0.006635
# 50%        0.001149
# 75%        0.010859
# max        0.053830
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.005947
# std        0.063617
# min       -0.205912
# 25%       -0.036879
# 50%        0.004978
# 75%        0.040913
# max        0.245584
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.004013
# std        0.065596
# min       -0.206329
# 25%       -0.037685
# 50%        0.002393
# 75%        0.039497
# max        0.254102
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.005249
# std        0.050848
# min       -0.172053
# 25%       -0.032509
# 50%       -0.010707
# 75%        0.020793
# max        0.210606
# dtype: float64
# =================++++++++++++++=================

# %%
Object.T_Test_Return()
# Out:
# ==============================T Test For Return==============================
# Result of T Test for Turnover Rank(TOP):
# Ttest_1sampResult(statistic=3.1690560760221005, pvalue=0.001719842998679821)
# Result of T Test for Turnover Rank(BOT):
# Ttest_1sampResult(statistic=3.991086569868179, pvalue=8.647418474987787e-05)
# Result of T Test for Turnover Rank(Diff):
# Ttest_1sampResult(statistic=1.3255901642596786, pvalue=0.1861855183243871)
# ==============================++++++++++++++==============================
# Result of T Test for Dollar Turnover Rank(TOP):
# Ttest_1sampResult(statistic=3.110460633856621, pvalue=0.002084563066691495)
# Result of T Test for Dollar Turnover Rank(BOT):
# Ttest_1sampResult(statistic=3.9350621924646267, pvalue=0.00010784100533582434)
# Result of T Test for Dollar Turnover Rank(Diff):
# Ttest_1sampResult(statistic=-0.7880630423001255, pvalue=0.4314064108855249)
# ==============================++++++++++++++==============================
# Result of T Test for Current Ratio Rank(TOP):
# Ttest_1sampResult(statistic=3.106839330551045, pvalue=0.0021092935118784475)
# Result of T Test for Current Ratio Rank(BOT):
# Ttest_1sampResult(statistic=3.5693092265131363, pvalue=0.0004290456722794224)
# Result of T Test for Current Ratio Rank(Diff):
# Ttest_1sampResult(statistic=0.17719868004452963, pvalue=0.8594958106478814)
# ==============================++++++++++++++==============================
# Result of T Test for Cash Ratio Rank(TOP):
# Ttest_1sampResult(statistic=3.5650820656265334, pvalue=0.00043567740821680333)
# Result of T Test for Cash Ratio Rank(BOT):
# Ttest_1sampResult(statistic=3.68766900944415, pvalue=0.00027763007550191566)
# Result of T Test for Cash Ratio Rank(Diff):
# Ttest_1sampResult(statistic=0.5914384952759414, pvalue=0.5547610535972163)
# ==============================++++++++++++++==============================
# Result of T Test for Quick Ratio Rank(TOP):
# Ttest_1sampResult(statistic=3.394358516963862, pvalue=0.0007998260910333054)
# Result of T Test for Quick Ratio Rank(BOT):
# Ttest_1sampResult(statistic=3.5138804815672042, pvalue=0.0005240333510147179)
# Result of T Test for Quick Ratio Rank(Diff):
# Ttest_1sampResult(statistic=0.6387037068585532, pvalue=0.5236003985900262)
# ==============================++++++++++++++==============================
# Result of T Test for Revenue Growth Rank(TOP):
# Ttest_1sampResult(statistic=3.8861725776431357, pvalue=0.00013049668700375637)
# Result of T Test for Revenue Growth Rank(BOT):
# Ttest_1sampResult(statistic=2.829886657618023, pvalue=0.005034619771863986)
# Result of T Test for Revenue Growth Rank(Diff):
# Ttest_1sampResult(statistic=2.5719453237978143, pvalue=0.01069150248879598)
# ==============================++++++++++++++==============================
# Result of T Test for COGS Growth Rank(TOP):
# Ttest_1sampResult(statistic=3.652466782954841, pvalue=0.0003163704965306887)
# Result of T Test for COGS Growth Rank(BOT):
# Ttest_1sampResult(statistic=3.39480126427137, pvalue=0.0007985912651962063)
# Result of T Test for COGS Growth Rank(Diff):
# Ttest_1sampResult(statistic=1.3627651807963408, pvalue=0.1741827913210172)
# ==============================++++++++++++++==============================
# Result of T Test for Operating Income Growth Rank(TOP):
# Ttest_1sampResult(statistic=4.192161821320901, pvalue=3.837174153787811e-05)
# Result of T Test for Operating Income Growth Rank(BOT):
# Ttest_1sampResult(statistic=2.6616909442699406, pvalue=0.00827881045475033)
# Result of T Test for Operating Income Growth Rank(Diff):
# Ttest_1sampResult(statistic=3.5456194941266093, pvalue=0.00046747201059754343)
# ==============================++++++++++++++==============================
# Result of T Test for Net Income Growth Rank(TOP):
# Ttest_1sampResult(statistic=3.7577915561448827, pvalue=0.00021339730758279492)
# Result of T Test for Net Income Growth Rank(BOT):
# Ttest_1sampResult(statistic=3.421001113789644, pvalue=0.000728608984492664)
# Result of T Test for Net Income Growth Rank(Diff):
# Ttest_1sampResult(statistic=0.09681050228531905, pvalue=0.9229544472958443)
# ==============================++++++++++++++==============================
# Result of T Test for EPS Basic Growth Rank(TOP):
# Ttest_1sampResult(statistic=3.915221058497962, pvalue=0.00011654436213578818)
# Result of T Test for EPS Basic Growth Rank(BOT):
# Ttest_1sampResult(statistic=3.305182892007721, pvalue=0.0010882814694211716)
# Result of T Test for EPS Basic Growth Rank(Diff):
# Ttest_1sampResult(statistic=0.9359381757299086, pvalue=0.3502082203670126)
# ==============================++++++++++++++==============================
# Result of T Test for Net Operating Cash Flow Growth Rank(TOP):
# Ttest_1sampResult(statistic=3.9118203678915013, pvalue=0.00011810143118124013)
# Result of T Test for Net Operating Cash Flow Growth Rank(BOT):
# Ttest_1sampResult(statistic=3.1132543808416706, pvalue=0.002065667260357904)
# Result of T Test for Net Operating Cash Flow Growth Rank(Diff):
# Ttest_1sampResult(statistic=1.9870517364488567, pvalue=0.048008087374281014)
# ==============================++++++++++++++==============================

# %%
Object.T_Test_Excess()
# Out:
# ==============================T Test For Excess Return==============================
# Result of T Test for Turnover Rank(TOP):
# Ttest_1sampResult(statistic=1.3544421590081592, pvalue=0.176818222474589)
# Result of T Test for Turnover Rank(BOT):
# Ttest_1sampResult(statistic=1.010649190461479, pvalue=0.3131615122528439)
# Result of T Test for Turnover Rank(Diff Excess):
# Ttest_1sampResult(statistic=-0.9757039308531325, pvalue=0.33015436552038435)
# ==============================++++++++++++++==============================
# Result of T Test for Dollar Turnover Rank(TOP):
# Ttest_1sampResult(statistic=0.9132647583221748, pvalue=0.36198320425209984)
# Result of T Test for Dollar Turnover Rank(BOT):
# Ttest_1sampResult(statistic=1.4349849141408193, pvalue=0.15254122078447116)
# Result of T Test for Dollar Turnover Rank(Diff Excess):
# Ttest_1sampResult(statistic=-2.3220668693623514, pvalue=0.021033307523969938)
# ==============================++++++++++++++==============================
# Result of T Test for Current Ratio Rank(TOP):
# Ttest_1sampResult(statistic=0.8407811030969049, pvalue=0.40127400716789463)
# Result of T Test for Current Ratio Rank(BOT):
# Ttest_1sampResult(statistic=0.8698957102914809, pvalue=0.3851918461871695)
# Result of T Test for Current Ratio Rank(Diff Excess):
# Ttest_1sampResult(statistic=-2.112491374656495, pvalue=0.03563612033562242)
# ==============================++++++++++++++==============================
# Result of T Test for Cash Ratio Rank(TOP):
# Ttest_1sampResult(statistic=1.1679191541593719, pvalue=0.24395198863768916)
# Result of T Test for Cash Ratio Rank(BOT):
# Ttest_1sampResult(statistic=1.0685898711358275, pvalue=0.2862852277662307)
# Result of T Test for Cash Ratio Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.7859453092005437, pvalue=0.07532006892983413)
# ==============================++++++++++++++==============================
# Result of T Test for Quick Ratio Rank(TOP):
# Ttest_1sampResult(statistic=1.0313133839399908, pvalue=0.3033905622854282)
# Result of T Test for Quick Ratio Rank(BOT):
# Ttest_1sampResult(statistic=0.8684439314708531, pvalue=0.38598426204700564)
# Result of T Test for Quick Ratio Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.7933698927310637, pvalue=0.07412239696099747)
# ==============================++++++++++++++==============================
# Result of T Test for Revenue Growth Rank(TOP):
# Ttest_1sampResult(statistic=1.3749781241042727, pvalue=0.1703692215401717)
# Result of T Test for Revenue Growth Rank(BOT):
# Ttest_1sampResult(statistic=0.4755254308660003, pvalue=0.6348277351482878)
# Result of T Test for Revenue Growth Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.0679827081912734, pvalue=0.28655848380939364)
# ==============================++++++++++++++==============================
# Result of T Test for COGS Growth Rank(TOP):
# Ttest_1sampResult(statistic=1.1945042524709046, pvalue=0.23341283110069155)
# Result of T Test for COGS Growth Rank(BOT):
# Ttest_1sampResult(statistic=0.8454121509083762, pvalue=0.3986891499313041)
# Result of T Test for COGS Growth Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.7284476873235681, pvalue=0.08514267195579392)
# ==============================++++++++++++++==============================
# Result of T Test for Operating Income Growth Rank(TOP):
# Ttest_1sampResult(statistic=1.7283539542646869, pvalue=0.08515949735302472)
# Result of T Test for Operating Income Growth Rank(BOT):
# Ttest_1sampResult(statistic=0.551261732313118, pvalue=0.581946609344932)
# Result of T Test for Operating Income Growth Rank(Diff Excess):
# Ttest_1sampResult(statistic=-0.7543092519664267, pvalue=0.45137346117529487)
# ==============================++++++++++++++==============================
# Result of T Test for Net Income Growth Rank(TOP):
# Ttest_1sampResult(statistic=1.372703909345745, pvalue=0.17107454977847897)
# Result of T Test for Net Income Growth Rank(BOT):
# Ttest_1sampResult(statistic=1.2847611992101793, pvalue=0.20006485664865323)
# Result of T Test for Net Income Growth Rank(Diff Excess):
# Ttest_1sampResult(statistic=-2.203431210382387, pvalue=0.02847668290018737)
# ==============================++++++++++++++==============================
# Result of T Test for EPS Basic Growth Rank(TOP):
# Ttest_1sampResult(statistic=1.4976028809600304, pvalue=0.1354979621253332)
# Result of T Test for EPS Basic Growth Rank(BOT):
# Ttest_1sampResult(statistic=1.2019916429089041, pvalue=0.2305040875424188)
# Result of T Test for EPS Basic Growth Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.9250440430317388, pvalue=0.05535844024061697)
# ==============================++++++++++++++==============================
# Result of T Test for Net Operating Cash Flow Growth Rank(TOP):
# Ttest_1sampResult(statistic=1.4810881362820016, pvalue=0.13984230983942342)
# Result of T Test for Net Operating Cash Flow Growth Rank(BOT):
# Ttest_1sampResult(statistic=0.9692267129880234, pvalue=0.3333688259444869)
# Result of T Test for Net Operating Cash Flow Growth Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.6355897370748784, pvalue=0.10318384567325123)
# ==============================++++++++++++++==============================

# %% [markdown]
# ## Plot Cumulative Return for each Factor

# %%
Object.Plot_Cum_TOP_Return()

# %%
Object.Plot_Cum_BOT_Return()

# %%
Object.Plot_Cum_TOP_Excess()

# %%
Object.Plot_Cum_BOT_Excess()

# %%
Object.Plot_Cum_Diff_Return()

# %%
Object.Plot_Cum_Diff_Excess()

# %% [markdown]
# # Combine Factors

# %%
# class Combine():
#     def __init__(self, df, SPY, Date):
#         self.df = df
#         self.SPY = SPY
#         self.Date = Date
        
#     def Combine_Factors(self):
#         self.data = self.df.copy()
#         self.data['Liquid Ratio Rank'] = (self.data['Cash Ratio Rank'] + self.data['Current Ratio Rank'] + self.data['Quick Ratio Rank']) / 3 
#         self.data['Turnover Combine Rank'] = (self.data['Turnover Rank'] + self.data['Dollar Turnover Rank']) / 2
#         self.data['Income Combine Rank'] = (self.data['COGS Growth Rank'] + self.data['Operating Income Growth Rank'] + self.data['Net Income Growth Rank']) / 3
        
#         self.data['Total Rank'] = (self.data['Revenue Growth Rank'] + self.data['Income Combine Rank'] +
#                                    self.data['EPS Basic Growth Rank'] + self.data['Net Operating Cash Flow Growth Rank'] + self.data['Liquid Ratio Rank'] +
#                                    self.data['Income Combine Rank']) / 6
               
#     def Get_Returns(self):
#         self.data_ = self.data.copy()
           
#         self.Return1 = []  # Used to store TOP return for each month
#         self.Excess1 = []  # Used to store TOP excess return for each month
#         self.Return2 = []  # Used to store BOT return for each month
#         self.Excess2 = []  # Used to store BOT excess return for each month
#         self.Diff = []  # Used to store diff return for each month
#         self.Diff_Excess = []  # Used to store diff excess return for each month
#         for date in Date:
#             DF = self.data_[date].copy()  # Divide the big df into small DF by date
#             N = int(len(DF)/10)   # We decide to long top 10% of universe and short bottom 10%
#             DF = DF.sort_values(by = ['Total Rank'], axis = 0, ascending = True)  # Sort by Turnover
#             #profit = ( DF.iloc[:N]['Return'].mean() - DF.iloc[-N:]['Return'].mean() ) / 2 
#             profit1 = DF.iloc[N]['Return'].mean()
#             profit2 = DF.iloc[-N:]['Return'].mean()
#             profit_SPY = self.SPY[date]['Return'].values[0]
#             diff = profit1 - profit2

#             self.Return1.append( profit1 )
#             self.Excess1.append( profit1 - profit_SPY )
#             self.Return2.append( profit2 )
#             self.Excess2.append( profit2 - profit_SPY )
#             self.Diff.append( diff )
#             self.Diff_Excess.append( diff - profit_SPY )

#     def Return_Summary(self):
#         print("=============++++++++++++++=============")
#         print("Summary for SPY Return:"); print(self.SPY['Return'].describe())
#         print("=============++++++++++++++=============")
#         print("Summary for Return(TOP):")
#         print(pd.Series(self.Return1).describe())
#         print("=============++++++++++++++=============")
#         print("Summary for Excess Return(TOP):")
#         print(pd.Series(self.Excess1).describe())
#         print("=============++++++++++++++=============")
#         print("Summary for Return(BOT):")
#         print(pd.Series(self.Return2).describe())
#         print("=============++++++++++++++=============")
#         print("Summary for Excess Return(BOT):")
#         print(pd.Series(self.Excess2).describe())
#         print("=============++++++++++++++=============")
#         print("Summary for Return(Diff):")
#         print(pd.Series(self.Diff).describe())
#         print("=============++++++++++++++=============")
#         print("Summary for Excess Return(Diff):")
#         print(pd.Series(self.Diff_Excess).describe())
#         print("=============++++++++++++++=============")
        
#     def T_Test(self):
#         from scipy import stats
#         print("==============================++++++++++++++==============================")
#         print("Result of T Test (TOP)")
#         print(stats.ttest_1samp(self.Excess1, 0))
#         print("Result of T Test (BOT)")
#         print(stats.ttest_1samp(self.Excess2, 0))
#         print("Result of T Test (Diff)")
#         print(stats.ttest_1samp(self.Diff, 0))
#         print("Result of T Test (Diff Excess)")
#         print(stats.ttest_1samp(self.Diff_Excess, 0))
#         print("==============================++++++++++++++==============================")
            
#     def Plot_hist_Return(self):
#         plt.figure(figsize=(30,4))
        
#         ax1 = plt.subplot(1,7,1)
#         plt.hist(self.SPY['Return'].values, bins=20)
#         plt.ylabel('Frequency')
#         plt.title('Distribution of SPY Return') 
        
#         ax2 = plt.subplot(1,7,2)
#         plt.hist(self.Return1, bins=20)
#         plt.ylabel('Frequency')
#         plt.title('Distribution of TOP Return')
            
#         ax3 = plt.subplot(1,7,3)
#         plt.hist(self.Excess1, bins=20)
#         plt.ylabel('Frequency')
#         plt.title('Distribution of TOP Excess Return') 
        
#         ax4 = plt.subplot(1,7,4)
#         plt.hist(self.Return2, bins=20)
#         plt.ylabel('Frequency')
#         plt.title('Distribution of BOT Return')
            
#         ax5 = plt.subplot(1,7,5)
#         plt.hist(self.Excess2, bins=20)
#         plt.ylabel('Frequency')
#         plt.title('Distribution of BOT Excess Return') 
        
#         ax6 = plt.subplot(1,7,6)
#         plt.hist(self.Diff, bins=20)
#         plt.ylabel('Frequency')
#         plt.title('Distribution of Diff Return')
            
#         ax7 = plt.subplot(1,7,7)
#         plt.hist(self.Diff_Excess, bins=20)
#         plt.ylabel('Frequency')
#         plt.title('Distribution of Diff Excess Return') 

#     def Plot_Cum_Return(self):
#         fig1 = plt.figure(figsize = (15, 6))
#         ax1 = fig1.add_subplot(111)
        
#         plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY Return')
        
#         plt.plot(self.Date, (pd.Series(self.Return1)+1).cumprod()-1, label = 'TOP Return')   
#         #plt.plot(self.Date, (pd.Series(self.Excess1)+1).cumprod()-1, label = 'TOP Excess Return') 
#         plt.plot(self.Date, (pd.Series(self.Return2)+1).cumprod()-1, label = 'BOT Return')   
#         #plt.plot(self.Date, (pd.Series(self.Excess2)+1).cumprod()-1, label = 'BOT Excess Return')
#         plt.plot(self.Date, (pd.Series(self.Diff)+1).cumprod()-1, label = 'Diff Return')   
#         #plt.plot(self.Date, (pd.Series(self.Diff_Excess)+1).cumprod()-1, label = 'Diff Excess Return') 
        
#         plt.tick_params(axis='x', which='major', labelsize=15)
#         plt.tick_params(axis='y', which='major', labelsize=15)
#         plt.xticks(np.arange(0, len(Date), step=12))
#         plt.ylabel('Cumulative Return', fontsize = 15)
#         locs, labels = plt.xticks() 
#         plt.setp(labels, rotation = 90)
#         plt.title('Cumulative Return for Combine Factor',fontsize =15)
        
#         ax1.legend(loc=2)
        
#     def Plot_Cum_Excess(self):
#         fig1 = plt.figure(figsize = (15, 6))
#         ax1 = fig1.add_subplot(111)
        
#         #plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY Return')
        
#         #plt.plot(self.Date, (pd.Series(self.Return1)+1).cumprod()-1, label = 'TOP Return')   
#         plt.plot(self.Date, (pd.Series(self.Excess1)+1).cumprod()-1, label = 'TOP Excess Return') 
#         #plt.plot(self.Date, (pd.Series(self.Return2)+1).cumprod()-1, label = 'BOT Return')   
#         plt.plot(self.Date, (pd.Series(self.Excess2)+1).cumprod()-1, label = 'BOT Excess Return')
#         #plt.plot(self.Date, (pd.Series(self.Diff)+1).cumprod()-1, label = 'Diff Return')   
#         plt.plot(self.Date, (pd.Series(self.Diff_Excess)+1).cumprod()-1, label = 'Diff Excess Return') 
        
#         plt.tick_params(axis='x', which='major', labelsize=15)
#         plt.tick_params(axis='y', which='major', labelsize=15)
#         plt.xticks(np.arange(0, len(Date), step=12))
#         plt.ylabel('Cumulative Return', fontsize = 15)
#         locs, labels = plt.xticks() 
#         plt.setp(labels, rotation = 90)
#         plt.title('Cumulative Excess Return for Combine Factor',fontsize =15)
        
#         ax1.legend(loc=2)

# %%
# class Combine():
#     def __init__(self, df, SPY, Date):
#         self.df = df
#         self.SPY = SPY
#         self.Date = Date
#         self.Factor_Rank = ['Liquidity Combine Rank', 'Growth Combine Rank', 'Total Rank']
        
#     def Combine_Factors(self):
#         self.data = self.df.copy()
#         self.data['Liquid Ratio Rank'] = (self.data['Cash Ratio Rank'] + self.data['Current Ratio Rank'] + self.data['Quick Ratio Rank']) / 3 
#         self.data['Turnover Combine Rank'] = (self.data['Turnover Rank'] + self.data['Dollar Turnover Rank']) / 2
#         self.data['Liquidity Combine Rank'] = (self.data['Liquid Ratio Rank'] + self.data['Turnover Combine Rank']) / 2
#         self.data['Growth Combine Rank'] = (self.data['Net Operating Cash Flow Growth Rank'] + self.data['EPS Basic Growth Rank'] + 
#                                             self.data['Revenue Growth Rank'] + self.data['COGS Growth Rank'] + 
#                                             self.data['Operating Income Growth Rank'] + self.data['Net Income Growth Rank']) / 6
        
#         self.data['Total Rank'] = (self.data['Liquidity Combine Rank'] + self.data['Growth Combine Rank']) / 2 
               
#     def Get_Returns(self):
#         self.data_ = self.data.copy()
           
#         self.Returns1 = {} # Used to store TOP each factor's return for each month
#         self.Returns2 = {} # Used to store BOT each factor's return for each month
#         self.Excesses1 = {} # Used to store TOP each factor's excess return for each month
#         self.Excesses2 = {} # Used to store BOT each factor's excess return for each month
#         self.Diffs = {} # Used to store each factor's diff return for each month
#         self.Diffs_Excess = {} # Used to store each factor's diff excess return for each month
           
#         for factor in self.Factor_Rank:
#             Return1 = []  # Used to store TOP return for each month
#             Return2 = []  # Used to store BOT return for each month
#             Excess1 = []  # Used to store TOP excess return for each month
#             Excess2 = []  # Used to store BOT excess return for each month
#             Diff = []    # Used to store return of difference between TOP and BOT for each month
#             Diff_Excess = []    # Used to store excess return of difference between TOP and BOT for each month
            
#             for date in Date:
#                 DF = self.data_[date].copy()  # Divide the big df into small DF by date
#                 N = int(len(DF)/10)   # We decide to long top 10% of universe and short bottom 10%
#                 DF = DF.sort_values(by = [factor], axis = 0, ascending = True)  # Sort by Turnover
#                 #profit = ( DF.iloc[:N]['Return'].mean() - DF.iloc[-N:]['Return'].mean() ) / 2 
#                 profit1 = DF.iloc[:N]['Return'].mean()
#                 profit2 = DF.iloc[-N:]['Return'].mean()
#                 profit_SPY = self.SPY[date]['Return'].values[0]
#                 diff = profit1 - profit2

#                 Return1.append( profit1 )
#                 Return2.append( profit2 )
#                 Excess1.append( profit1 - profit_SPY )
#                 Excess2.append( profit2 - profit_SPY )
#                 Diff.append( diff )
#                 Diff_Excess.append( diff - profit_SPY )
                
#             self.Returns1[factor] = Return1 
#             self.Returns2[factor] = Return2 
#             self.Excesses1[factor] = Excess1
#             self.Excesses2[factor] = Excess2
#             self.Diffs[factor] = Diff
#             self.Diffs_Excess[factor] = Diff_Excess

#     def Return_Summary(self):
#         print("Summary for SPY Return:"); print(self.SPY['Return'].describe())
#         print("=============++++++++++++++=============")
        
#         for key in self.Factor_Rank:
#             print("=================" + key + "=================")
#             print("Summary for TOP Return:"); print(pd.Series(self.Returns1[key]).describe(), "\n")
#             print("Summary for BOT Return:"); print(pd.Series(self.Returns2[key]).describe(), "\n")
#             print("Summary for Diff Return:"); print(pd.Series(self.Diffs[key]).describe(), "\n")
#             print("Summary for TOP Excess Return:"); print(pd.Series(self.Excesses1[key]).describe(), "\n")
#             print("Summary for BOT Excess Return:"); print(pd.Series(self.Excesses2[key]).describe(), "\n")
#             print("Summary for Diff Excess Return:"); print(pd.Series(self.Diffs_Excess[key]).describe())
#             print("=================++++++++++++++=================")
        
#     def T_Test(self):
#         from scipy import stats
#         print("==============================T Test For Return==============================")
#         for factor in self.Factor_Rank:
#             print("Result of T Test for " + factor + "(TOP):")
#             print(stats.ttest_1samp(self.Returns1[factor], 0))
#             print("Result of T Test for " + factor + "(BOT):")
#             print(stats.ttest_1samp(self.Returns2[factor], 0))
#             print("Result of T Test for " + factor + "(Diff):")
#             print(stats.ttest_1samp(self.Diffs[factor], 0))
#             print("==============================++++++++++++++==============================")
            
#     def T_Test_Excess(self):
#         from scipy import stats
#         print("==============================T Test For Excess Return==============================")
#         for factor in self.Factor_Rank:
#             print("Result of T Test for " + factor + "(TOP):")
#             print(stats.ttest_1samp(self.Excesses1[factor], 0))
#             print("Result of T Test for " + factor + "(BOT):")
#             print(stats.ttest_1samp(self.Excesses2[factor], 0))
#             print("Result of T Test for " + factor + "(Diff Excess):")
#             print(stats.ttest_1samp(self.Diffs_Excess[factor], 0))
#             print("==============================++++++++++++++==============================")
            
#     def Plot_hist_Return(self):
#         plt.figure(figsize=(15,3))
#         count = 0
        
#         N = len(self.Factor_Rank)
#         for key in self.Factor_Rank:
#             count += 1
#             ax = plt.subplot(N,6,count)
#             plt.hist(self.Returns1[key], bins=20)
#             plt.ylabel('Frequency')
#             plt.title('Distribution of TOP Return from' + key)
            
#             count += 1
#             ax = plt.subplot(N,6,count)
#             plt.hist(self.Excesses1[key], bins=20)
#             plt.ylabel('Frequency')
#             plt.title('Distribution of TOP Excess Return from' + key)
            
#             count += 1
#             ax = plt.subplot(N,6,count)
#             plt.hist(self.Returns2[key], bins=20)
#             plt.ylabel('Frequency')
#             plt.title('Distribution of BOT Return from' + key)
            
#             count += 1
#             ax = plt.subplot(N,6,count)
#             plt.hist(self.Excesses2[key], bins=20)
#             plt.ylabel('Frequency')
#             plt.title('Distribution of BOT Excess Return from' + key)
            
#             count += 1
#             ax = plt.subplot(N,6,count)
#             plt.hist(self.Diffs[key], bins=20)
#             plt.ylabel('Frequency')
#             plt.title('Distribution of Diff Return from' + key)
            
#             count += 1
#             ax = plt.subplot(N,6,count)
#             plt.hist(self.Diffs_Excess[key], bins=20)
#             plt.ylabel('Frequency')
#             plt.title('Distribution of Diff Excess Return from' + key)

#     def Plot_Cum_TOP_Return(self):
#         fig1 = plt.figure(figsize = (20, 10))
#         ax1 = fig1.add_subplot(111)
        
#         plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
#         for factor in self.Factor_Rank:
#             plt.plot(self.Date, (pd.Series(self.Returns1[factor])+1).cumprod()-1, label = factor) 
            
#         plt.tick_params(axis='x', which='major', labelsize=15)
#         plt.tick_params(axis='y', which='major', labelsize=15)
#         plt.xticks(np.arange(0, len(Date), step=12))
#         plt.ylabel('Cumulative Return', fontsize = 15)
#         locs, labels = plt.xticks() 
#         plt.setp(labels, rotation = 90)
#         plt.title('Cumulative Returns for each Factor (TOP)',fontsize =15)
        
# #         colormap = plt.cm.gist_ncar
# #         colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]
        
# #         for i,j in enumerate(ax1.lines):
# #             j.set_color(colors[i])
#         ax1.legend(loc=2)
        
#     def Plot_Cum_TOP_Excess(self):

#         fig1 = plt.figure(figsize = (20, 10))
#         ax1 = fig1.add_subplot(111)
        
#         #plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black') 

#         for factor in self.Factor_Rank:
#             plt.plot(self.Date, (pd.Series(self.Excesses1[factor])+1).cumprod()-1, label = factor) 
 
#         plt.tick_params(axis='x', which='major', labelsize=15)
#         plt.tick_params(axis='y', which='major', labelsize=15)
#         plt.xticks(np.arange(0, len(Date), step=12))
#         plt.ylabel('Cumulative Return', fontsize = 15)
#         locs, labels = plt.xticks() 
#         plt.setp(labels, rotation = 90)
#         plt.title('Cumulative Excess Returns for each Factor (TOP)',fontsize =15)

# #         colormap = plt.cm.gist_ncar
# #         colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]

# #         for i,j in enumerate(ax1.lines):
# #             j.set_color(colors[i])
#         ax1.legend(loc=2)
        
#     def Plot_Cum_BOT_Return(self):
#         fig1 = plt.figure(figsize = (20, 10))
#         ax1 = fig1.add_subplot(111)
        
#         plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
#         for factor in self.Factor_Rank:
#             plt.plot(self.Date, (pd.Series(self.Returns2[factor])+1).cumprod()-1, label = factor) 
            
#         plt.tick_params(axis='x', which='major', labelsize=15)
#         plt.tick_params(axis='y', which='major', labelsize=15)
#         plt.xticks(np.arange(0, len(Date), step=12))
#         plt.ylabel('Cumulative Return', fontsize = 15)
#         locs, labels = plt.xticks() 
#         plt.setp(labels, rotation = 90)
#         plt.title('Cumulative Returns for each Factor (BOT)',fontsize =15)
        
# #         colormap = plt.cm.gist_ncar
# #         colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]
        
# #         for i,j in enumerate(ax1.lines):
# #             j.set_color(colors[i])
#         ax1.legend(loc=2)
        
#     def Plot_Cum_BOT_Excess(self):

#         fig1 = plt.figure(figsize = (20, 10))
#         ax1 = fig1.add_subplot(111)
        
#         #plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black') 

#         for factor in self.Factor_Rank:
#             plt.plot(self.Date, (pd.Series(self.Excesses2[factor])+1).cumprod()-1, label = factor) 
 
#         plt.tick_params(axis='x', which='major', labelsize=15)
#         plt.tick_params(axis='y', which='major', labelsize=15)
#         plt.xticks(np.arange(0, len(Date), step=12))
#         plt.ylabel('Cumulative Return', fontsize = 15)
#         locs, labels = plt.xticks() 
#         plt.setp(labels, rotation = 90)
#         plt.title('Cumulative Excess Returns for each Factor (BOT)',fontsize =15)

# #         colormap = plt.cm.gist_ncar
# #         colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]

# #         for i,j in enumerate(ax1.lines):
# #             j.set_color(colors[i])
#         ax1.legend(loc=2)
        
#     def Plot_Cum_Diff_Return(self):
#         fig1 = plt.figure(figsize = (20, 10))
#         ax1 = fig1.add_subplot(111)
        
#         plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
#         for factor in self.Factor_Rank:
#             plt.plot(self.Date, (pd.Series(self.Diffs[factor])+1).cumprod()-1, label = factor) 
            
#         plt.tick_params(axis='x', which='major', labelsize=15)
#         plt.tick_params(axis='y', which='major', labelsize=15)
#         plt.xticks(np.arange(0, len(Date), step=12))
#         plt.ylabel('Cumulative Return', fontsize = 15)
#         locs, labels = plt.xticks() 
#         plt.setp(labels, rotation = 90)
#         plt.title('Cumulative Returns for each Factor (BOT)',fontsize =15)
        
# #         colormap = plt.cm.gist_ncar
# #         colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]
        
# #         for i,j in enumerate(ax1.lines):
# #             j.set_color(colors[i])
#         ax1.legend(loc=2)
        
#     def Plot_Cum_Diff_Excess(self):
#         fig1 = plt.figure(figsize = (20, 10))
#         ax1 = fig1.add_subplot(111)
        
#         #plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
#         for factor in self.Factor_Rank:
#             plt.plot(self.Date, (pd.Series(self.Diffs_Excess[factor])+1).cumprod()-1, label = factor) 
            
#         plt.tick_params(axis='x', which='major', labelsize=15)
#         plt.tick_params(axis='y', which='major', labelsize=15)
#         plt.xticks(np.arange(0, len(Date), step=12))
#         plt.ylabel('Cumulative Return', fontsize = 15)
#         locs, labels = plt.xticks() 
#         plt.setp(labels, rotation = 90)
#         plt.title('Cumulative Returns for each Factor (BOT)',fontsize =15)
        
# #         colormap = plt.cm.gist_ncar
# #         colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]
        
# #         for i,j in enumerate(ax1.lines):
# #             j.set_color(colors[i])
#         ax1.legend(loc=2)

# %%
Combine_Rank = ['Liquidity Combine Rank', 'Growth Combine Rank', 'Total Rank']
Object2 = Solve(df, SPY, Date, Combine_Rank)

# %%
#Object2 = Combine(df, SPY, Date)

# %% [markdown]
# ## Combine All these Factors into one

# %%
Object2.Combine_Factors()

# %% [markdown]
# ## Calculate Return

# %%
Object2.Get_Returns()

# %% [markdown]
# ## Give a Summary for Return and T Test for Excess Return

# %%
Object2.Return_Summary()
# Out:
# Summary for SPY Return:
# count    252.000000
# mean       0.007206
# std        0.046654
# min       -0.167743
# 25%       -0.019238
# 50%        0.012929
# 75%        0.034528
# max        0.157330
# Name: Return, dtype: float64
# =============++++++++++++++=============
# =================Liquidity Combine Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.012308
# std        0.061198
# min       -0.236279
# 25%       -0.024533
# 50%        0.015993
# 75%        0.057277
# max        0.197964
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.010652
# std        0.042188
# min       -0.160932
# 25%       -0.010145
# 50%        0.014649
# 75%        0.034032
# max        0.162208
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.001655
# std        0.035428
# min       -0.115074
# 25%       -0.020023
# 50%        0.001612
# 75%        0.022952
# max        0.151196
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.005124
# std        0.072185
# min       -0.201370
# 25%       -0.041360
# 50%        0.007318
# 75%        0.044684
# max        0.266699
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.003469
# std        0.054894
# min       -0.151706
# 25%       -0.028863
# 50%        0.001543
# 75%        0.035694
# max        0.220509
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.005528
# std        0.060599
# min       -0.191283
# 25%       -0.041978
# 50%       -0.008033
# 75%        0.030188
# max        0.208114
# dtype: float64
# =================++++++++++++++=================
# =================Growth Combine Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.013577
# std        0.051452
# min       -0.248872
# 25%       -0.010442
# 50%        0.016612
# 75%        0.046847
# max        0.179467
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.011552
# std        0.052715
# min       -0.187062
# 25%       -0.017443
# 50%        0.013702
# 75%        0.045217
# max        0.227075
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.002025
# std        0.024923
# min       -0.096131
# 25%       -0.008727
# 50%        0.003280
# 75%        0.015271
# max        0.094665
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.006394
# std        0.063200
# min       -0.205096
# 25%       -0.033888
# 50%        0.005285
# 75%        0.040943
# max        0.266804
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.004368
# std        0.063409
# min       -0.206627
# 25%       -0.035546
# 50%        0.002227
# 75%        0.038349
# max        0.238378
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.005158
# std        0.053957
# min       -0.253461
# 25%       -0.034628
# 50%       -0.009643
# 75%        0.023952
# max        0.164963
# dtype: float64
# =================++++++++++++++=================
# =================Total Rank=================
# Summary for TOP Return:
# count    251.000000
# mean       0.013000
# std        0.059353
# min       -0.265244
# 25%       -0.018997
# 50%        0.017492
# 75%        0.053522
# max        0.205586
# dtype: float64
#
# Summary for BOT Return:
# count    251.000000
# mean       0.009617
# std        0.047382
# min       -0.194505
# 25%       -0.015061
# 50%        0.011835
# 75%        0.040934
# max        0.209537
# dtype: float64
#
# Summary for Diff Return:
# count    251.000000
# mean       0.003383
# std        0.032303
# min       -0.109287
# 25%       -0.015889
# 50%        0.003630
# 75%        0.021033
# max        0.117944
# dtype: float64
#
# Summary for TOP Excess Return:
# count    251.000000
# mean       0.005817
# std        0.069900
# min       -0.208042
# 25%       -0.036236
# 50%        0.007778
# 75%        0.042026
# max        0.292923
# dtype: float64
#
# Summary for BOT Excess Return:
# count    251.000000
# mean       0.002434
# std        0.058433
# min       -0.167542
# 25%       -0.033981
# 50%       -0.001174
# 75%        0.036009
# max        0.235848
# dtype: float64
#
# Summary for Diff Excess Return:
# count    251.000000
# mean      -0.003800
# std        0.058503
# min       -0.210700
# 25%       -0.037270
# 50%       -0.008520
# 75%        0.025988
# max        0.184960
# dtype: float64
# =================++++++++++++++=================

# %%
Object2.T_Test_Return()
# Out:
# ==============================T Test For Return==============================
# Result of T Test for Liquidity Combine Rank(TOP):
# Ttest_1sampResult(statistic=3.1862302774085967, pvalue=0.0016247111161740656)
# Result of T Test for Liquidity Combine Rank(BOT):
# Ttest_1sampResult(statistic=4.000338738806145, pvalue=8.335802058932011e-05)
# Result of T Test for Liquidity Combine Rank(Diff):
# Ttest_1sampResult(statistic=0.7402786472671945, pvalue=0.4598255844635628)
# ==============================++++++++++++++==============================
# Result of T Test for Growth Combine Rank(TOP):
# Ttest_1sampResult(statistic=4.180647749136306, pvalue=4.0233020197223396e-05)
# Result of T Test for Growth Combine Rank(BOT):
# Ttest_1sampResult(statistic=3.471793775223159, pvalue=0.0006089647799802306)
# Result of T Test for Growth Combine Rank(Diff):
# Ttest_1sampResult(statistic=1.2874612063056377, pvalue=0.1991241755099246)
# ==============================++++++++++++++==============================
# Result of T Test for Total Rank(TOP):
# Ttest_1sampResult(statistic=3.470214541440922, pvalue=0.0006123897297338338)
# Result of T Test for Total Rank(BOT):
# Ttest_1sampResult(statistic=3.2156722070363606, pvalue=0.0014728802224802159)
# Result of T Test for Total Rank(Diff):
# Ttest_1sampResult(statistic=1.6593085958873959, pvalue=0.09830753374576691)
# ==============================++++++++++++++==============================

# %%
Object2.T_Test_Excess()
# Out:
# ==============================T Test For Excess Return==============================
# Result of T Test for Liquidity Combine Rank(TOP):
# Ttest_1sampResult(statistic=1.1246251397715263, pvalue=0.26182653492461)
# Result of T Test for Liquidity Combine Rank(BOT):
# Ttest_1sampResult(statistic=1.0011075864694965, pvalue=0.317742781705355)
# Result of T Test for Liquidity Combine Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.445322064735291, pvalue=0.14961976016669498)
# ==============================++++++++++++++==============================
# Result of T Test for Growth Combine Rank(TOP):
# Ttest_1sampResult(statistic=1.6027380607574404, pvalue=0.11025516938464773)
# Result of T Test for Growth Combine Rank(BOT):
# Ttest_1sampResult(statistic=1.0914170685713076, pvalue=0.27614013322544523)
# Result of T Test for Growth Combine Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.5146000055660467, pvalue=0.13113698752649974)
# ==============================++++++++++++++==============================
# Result of T Test for Total Rank(TOP):
# Ttest_1sampResult(statistic=1.3183844208282343, pvalue=0.18858156573900373)
# Result of T Test for Total Rank(BOT):
# Ttest_1sampResult(statistic=0.6598041450909157, pvalue=0.5099869034388662)
# Result of T Test for Total Rank(Diff Excess):
# Ttest_1sampResult(statistic=-1.0291820484576308, pvalue=0.3043888211443411)
# ==============================++++++++++++++==============================

# %% [markdown]
# ## Plot Cumulative Return

# %%
#Object2.Plot_hist_Return()

# %%
Object2.Plot_Cum_TOP_Return()

# %%
Object2.Plot_Cum_TOP_Excess()

# %%
Object2.Plot_Cum_BOT_Return()

# %%
Object2.Plot_Cum_BOT_Excess()

# %%
Object2.Plot_Cum_Diff_Return()

# %%
Object2.Plot_Cum_Diff_Excess()

# %% [markdown]
# # Calculate Alpha & Beta

# %%
Return_TOP = Object.Returns1
Return_BOT = Object.Returns2
Return_Diff = Object.Diffs

Excess_TOP = Object.Excesses1
Excess_BOT = Object.Excesses2
Excess_Diff = Object.Diffs_Excess

Rm = Object.SPY.iloc[1:].values.ravel()

Rf = 0.0781 / 12   # 20-Year Risk-Free Rate from Jan. 1995, /12 -> Monthly Return

# %%
class Indicators():
    def __init__(self, Return_TOP, Return_BOT, Return_Diff, Rm, Rf, Factor_Rank):
        self.Return_TOP = Return_TOP
        self.Return_BOT = Return_BOT
        self.Return_DIF = Return_Diff
#         self.Excess_TOP = Excess_TOP
#         self.Excess_BOT = Excess_BOT
#         self.Excess_Diff = Excess_Diff
        self.Rm = Rm
        self.Rf = Rf
#         self.Date = Date
        self.Factor_Rank = Factor_Rank
        
    def Cal_Beta(self):
        self.Beta_TOP = {}
        self.Beta_BOT = {}
        self.Beta_DIF = {}
        Variance_Rm = np.var(self.Rm)
        
        for key in self.Factor_Rank:
            self.Beta_TOP[key] = np.cov(self.Return_TOP[key], self.Rm)[0,1]
            self.Beta_BOT[key] = np.cov(self.Return_BOT[key], self.Rm)[0,1]
            self.Beta_DIF[key] = np.cov(self.Return_DIF[key], self.Rm)[0,1]
        
    def Cal_Alpha(self):        
        self.Alpha_TOP = {}
        self.Alpha_BOT = {}
        self.Alpha_DIF = {}
        
        for key in self.Factor_Rank:
            R_TOP = [];  R_BOT = [];  R_DIF = []
            for i in range(251):
                R_TOP.append(self.Return_TOP[key][i] - self.Rf - self.Beta_TOP[key] * (self.Rm[i] - self.Rf))
                R_BOT.append(self.Return_BOT[key][i] - self.Rf - self.Beta_BOT[key] * (self.Rm[i] - self.Rf))
                R_DIF.append(self.Return_DIF[key][i] - self.Rf - self.Beta_DIF[key] * (self.Rm[i] - self.Rf))
                
            self.Alpha_TOP[key] = R_TOP
            self.Alpha_BOT[key] = R_BOT
            self.Alpha_DIF[key] = R_DIF
            
    def Summary_Alpha(self):
        from scipy import stats
        for key in self.Factor_Rank:  
            print("============================" + key + "============================")
            print("Mean of " + key + "'s Alpha (TOP): ", np.mean(self.Alpha_TOP[key]))
            print("Result of T Test for " + key + "'s Alpha is(TOP): ")
            print(stats.ttest_1samp(self.Alpha_TOP[key], 0), "\n")
            
            print("Mean of " + key + "'s Alpha (BOT): ", np.mean(self.Alpha_BOT[key]))
            print("Result of T Test for " + key + "'s Alpha is(BOT): ")
            print(stats.ttest_1samp(self.Alpha_BOT[key], 0), "\n")
            
            print("Mean of " + key + "'s Alpha (DIF): ", np.mean(self.Alpha_DIF[key]))
            print("Result of T Test for " + key + "'s Alpha is(DIF): ")
            print(stats.ttest_1samp(self.Alpha_DIF[key], 0), "\n")    
            
        
        print("============================++++++++++++++============================")

# %% [markdown]
# ## Single Factors

# %%
Object3 = Indicators(Return_TOP, Return_BOT, Return_Diff, Rm, Rf, Factor_Rank)

# %%
Object3.Cal_Beta()
Object3.Cal_Alpha()

# %%
Object3.Summary_Alpha()
# Out:
# ============================Turnover Rank============================
# Mean of Turnover Rank's Alpha (TOP):  0.007559537372892068
# Result of T Test for Turnover Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.7029394501093698, pvalue=0.0898222349963655)
#
# Mean of Turnover Rank's Alpha (BOT):  0.0042531490061843685
# Result of T Test for Turnover Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.5774741334999738, pvalue=0.1159509564723019)
#
# Mean of Turnover Rank's Alpha (DIF):  -0.003201944966625633
# Result of T Test for Turnover Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-1.2837550922779186, pvalue=0.20041621736160822)
#
# ============================Dollar Turnover Rank============================
# Mean of Dollar Turnover Rank's Alpha (TOP):  0.0046170163633052815
# Result of T Test for Dollar Turnover Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.290863966589437, pvalue=0.19794329208910158)
#
# Mean of Dollar Turnover Rank's Alpha (BOT):  0.0061634894065097385
# Result of T Test for Dollar Turnover Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.9141597197060753, pvalue=0.05674141928794011)
#
# Mean of Dollar Turnover Rank's Alpha (DIF):  -0.008054806376537792
# Result of T Test for Dollar Turnover Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-4.104438505970176, pvalue=5.490668258596015e-05)
#
# ============================Current Ratio Rank============================
# Mean of Current Ratio Rank's Alpha (TOP):  0.004167663785026798
# Result of T Test for Current Ratio Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.2128756383083898, pvalue=0.22632218515128574)
#
# Mean of Current Ratio Rank's Alpha (BOT):  0.00391797095014174
# Result of T Test for Current Ratio Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.341339834624761, pvalue=0.18102738425719955)
#
# Mean of Current Ratio Rank's Alpha (DIF):  -0.006258640498448275
# Result of T Test for Current Ratio Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-4.44167419348435, pvalue=1.3411771584088387e-05)
#
# ============================Cash Ratio Rank============================
# Mean of Cash Ratio Rank's Alpha (TOP):  0.005605511069613886
# Result of T Test for Cash Ratio Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.6497164414703311, pvalue=0.1002567922689694)
#
# Mean of Cash Ratio Rank's Alpha (BOT):  0.004701190992930714
# Result of T Test for Cash Ratio Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.546684647026006, pvalue=0.12320422178942823)
#
# Mean of Cash Ratio Rank's Alpha (DIF):  -0.005604013256650163
# Result of T Test for Cash Ratio Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-3.665730750170388, pvalue=0.00030121107944040967)
#
# ============================Quick Ratio Rank============================
# Mean of Quick Ratio Rank's Alpha (TOP):  0.004985529735457529
# Result of T Test for Quick Ratio Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.4723521761910323, pvalue=0.14218358224788777)
#
# Mean of Quick Ratio Rank's Alpha (BOT):  0.003963920302911811
# Result of T Test for Quick Ratio Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.3301255660775404, pvalue=0.1846890617067129)
#
# Mean of Quick Ratio Rank's Alpha (DIF):  -0.005486723900787617
# Result of T Test for Quick Ratio Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-3.4304439594518277, pvalue=0.0007048230662009804)
#
# ============================Revenue Growth Rank============================
# Mean of Revenue Growth Rank's Alpha (TOP):  0.0061766847404811295
# Result of T Test for Revenue Growth Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.8923671308216037, pvalue=0.059597435115229115)
#
# Mean of Revenue Growth Rank's Alpha (BOT):  0.0025340723405235226
# Result of T Test for Revenue Growth Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=0.7930936430832604, pvalue=0.4284752980924176)
#
# Mean of Revenue Growth Rank's Alpha (DIF):  -0.002865720933375727
# Result of T Test for Revenue Growth Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-2.023422609298747, pvalue=0.0440936505639159)
#
# ============================COGS Growth Rank============================
# Mean of COGS Growth Rank's Alpha (TOP):  0.0055376521794681405
# Result of T Test for COGS Growth Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.6791253451214376, pvalue=0.09437695374445086)
#
# Mean of COGS Growth Rank's Alpha (BOT):  0.003931196271337669
# Result of T Test for COGS Growth Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.2784340029920298, pvalue=0.20228202865533568)
#
# Mean of COGS Growth Rank's Alpha (DIF):  -0.004901877425202861
# Result of T Test for COGS Growth Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-4.158377196504096, pvalue=4.408047250957544e-05)
#
# ============================Operating Income Growth Rank============================
# Mean of Operating Income Growth Rank's Alpha (TOP):  0.007655876757052001
# Result of T Test for Operating Income Growth Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=2.2660281771149684, pvalue=0.024305182277985907)
#
# Mean of Operating Income Growth Rank's Alpha (BOT):  0.002957844111548694
# Result of T Test for Operating Income Growth Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=0.8317254513760233, pvalue=0.4063576514615894)
#
# Mean of Operating Income Growth Rank's Alpha (DIF):  -0.0018103006878300279
# Result of T Test for Operating Income Growth Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-1.3662569405402893, pvalue=0.17308597772656717)
#
# ============================Net Income Growth Rank============================
# Mean of Net Income Growth Rank's Alpha (TOP):  0.006182347063513814
# Result of T Test for Net Income Growth Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.8307455968733075, pvalue=0.06832882940365731)
#
# Mean of Net Income Growth Rank's Alpha (BOT):  0.006080915931132355
# Result of T Test for Net Income Growth Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.6525347560182229, pvalue=0.09968088227046584)
#
# Mean of Net Income Growth Rank's Alpha (DIF):  -0.006406902200951872
# Result of T Test for Net Income Growth Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-6.117839863128243, pvalue=3.6369518627111737e-09)
#
# ============================EPS Basic Growth Rank============================
# Mean of EPS Basic Growth Rank's Alpha (TOP):  0.006684114398333155
# Result of T Test for EPS Basic Growth Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.9838157532219878, pvalue=0.04837017257936033)
#
# Mean of EPS Basic Growth Rank's Alpha (BOT):  0.005734167157737912
# Result of T Test for EPS Basic Growth Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.548194725439984, pvalue=0.12284036072240485)
#
# Mean of EPS Basic Growth Rank's Alpha (DIF):  -0.005558386092738089
# Result of T Test for EPS Basic Growth Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-5.476969954671947, pvalue=1.0532246340978952e-07)
#
# ============================Net Operating Cash Flow Growth Rank============================
# Mean of Net Operating Cash Flow Growth Rank's Alpha (TOP):  0.006622266950716182
# Result of T Test for Net Operating Cash Flow Growth Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.9729951688048317, pvalue=0.04959772629976951)
#
# Mean of Net Operating Cash Flow Growth Rank's Alpha (BOT):  0.004687981512511906
# Result of T Test for Net Operating Cash Flow Growth Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.3036265066350088, pvalue=0.19356013193520152)
#
# Mean of Net Operating Cash Flow Growth Rank's Alpha (DIF):  -0.004574047895129058
# Result of T Test for Net Operating Cash Flow Growth Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-4.6990892937103474, pvalue=4.318188259676701e-06)
#
# ============================++++++++++++++============================

# %% [markdown]
# ## Combine Factors

# %%
Return_TOP2 = Object2.Returns1
Return_BOT2 = Object2.Returns2
Return_Diff2 = Object2.Diffs

Rm2 = Object2.SPY.iloc[1:].values.ravel()

Rf2 = 0.0781 / 12   # 20-Year Risk-Free Rate from Jan. 1995, /12 -> Monthly Return
Combine_Rank = ['Liquidity Combine Rank', 'Growth Combine Rank', 'Total Rank']

# %%
Object4 = Indicators(Return_TOP2, Return_BOT2, Return_Diff2, Rm2, Rf2, Combine_Rank)
Object4.Cal_Beta()
Object4.Cal_Alpha()

# %%
Object4.Summary_Alpha()
# Out:
# ============================Liquidity Combine Rank============================
# Mean of Liquidity Combine Rank's Alpha (TOP):  0.0057992340230464835
# Result of T Test for Liquidity Combine Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.5013501735530395, pvalue=0.1345269568454619)
#
# Mean of Liquidity Combine Rank's Alpha (BOT):  0.004143756908620568
# Result of T Test for Liquidity Combine Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.5563178210007385, pvalue=0.12089752856002056)
#
# Mean of Liquidity Combine Rank's Alpha (DIF):  -0.004852856218907417
# Result of T Test for Liquidity Combine Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-2.170174509556436, pvalue=0.030935520880900624)
#
# ============================Growth Combine Rank============================
# Mean of Growth Combine Rank's Alpha (TOP):  0.007068654633323437
# Result of T Test for Growth Combine Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=2.176690294399483, pvalue=0.03043982055443797)
#
# Mean of Growth Combine Rank's Alpha (BOT):  0.0050432882286516574
# Result of T Test for Growth Combine Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.5158195854181722, pvalue=0.13082833744158992)
#
# Mean of Growth Combine Rank's Alpha (DIF):  -0.004482966928661557
# Result of T Test for Growth Combine Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-2.8497425183834437, pvalue=0.004740173400341236)
#
# ============================Total Rank============================
# Mean of Total Rank's Alpha (TOP):  0.006491868828675585
# Result of T Test for Total Rank's Alpha is(TOP):
# Ttest_1sampResult(statistic=1.7329557816397938, pvalue=0.08433664128913276)
#
# Mean of Total Rank's Alpha (BOT):  0.003108545530355947
# Result of T Test for Total Rank's Alpha is(BOT):
# Ttest_1sampResult(statistic=1.0395113213397202, pvalue=0.29957129499595053)
#
# Mean of Total Rank's Alpha (DIF):  -0.003125010035013695
# Result of T Test for Total Rank's Alpha is(DIF):
# Ttest_1sampResult(statistic=-1.5326655522879502, pvalue=0.12662273618823208)
#
# ============================++++++++++++++============================

# %% [markdown]
# # Calculate Max DrawDown

# %%
def MaxDrawdown(return_list):
    return_list.insert(0,0)
    a = pd.Series(return_list)
    a += 1
    a = a.cumprod()
    return_list = list(a)
    i = np.argmax((np.maximum.accumulate(return_list) - return_list) / np.maximum.accumulate(return_list))
    if i == 0:
        return 0
    j = np.argmax(return_list[:i])
    return (return_list[j] - return_list[i]) / (return_list[j])

# %%
Max_DrawDown_TOP = {}
Max_DrawDown_BOT = {}
Max_DrawDown_DIF = {}

for key in Factor_Rank:
    Max_DrawDown_TOP[key] = MaxDrawdown(Return_TOP[key])
    Max_DrawDown_BOT[key] = MaxDrawdown(Return_BOT[key])
    Max_DrawDown_DIF[key] = MaxDrawdown(Return_Diff[key])

# %% [markdown]
# ## Long Top

# %%
for key in Factor_Rank:
    print(Max_DrawDown_TOP[key])
# Out:
# 0.5516802185150632
# 0.5718167471037425
# 0.4858727961334394
# 0.45977716942956043
# 0.43820552323491724
# 0.5629175288371561
# 0.49563947470297887
# 0.5672571216985376
# 0.577779680176012
# 0.5818017342977642
# 0.518895683854888

# %% [markdown]
# ## Long Bottom

# %%
for key in Factor_Rank:
    print(Max_DrawDown_BOT[key])
# Out:
# 0.4794663573151498
# 0.5353711011828558
# 0.532498791228111
# 0.49794739224045875
# 0.5205875444302139
# 0.4767718398645706
# 0.4192354093843321
# 0.5572050752290831
# 0.587286430407662
# 0.5810693077272988
# 0.5444456718601939

# %% [markdown]
# ## Long Top & Short Bottom

# %%
for key in Factor_Rank:
    print(Max_DrawDown_DIF[key])
# Out:
# 0.3269311291528216
# 0.6675982201847922
# 0.23010802699272737
# 0.35081019940152935
# 0.3419813770176369
# 0.3238652297187461
# 0.2003197041981
# 0.3268482762128956
# 0.3657524125528642
# 0.2921536738169959
# 0.12444589918625552

# %%
returns = [1.0, 1.01, 1.05, 1.1, 1.11, 1.07, 1.03, 1.03, 1.01, 1.02]

max_draw_down = 0
temp_max_value = 0
for i in range(1, len(returns)):
    temp_max_value = max(temp_max_value, returns[i-1])
    max_draw_down = min(max_draw_down, returns[i]/temp_max_value-1)
    print(i, temp_max_value, max_draw_down)
# Out:
# 1 1.0 0
# 2 1.01 0
# 3 1.05 0
# 4 1.1 0
# 5 1.11 -0.03603603603603611
# 6 1.11 -0.07207207207207211
# 7 1.11 -0.07207207207207211
# 8 1.11 -0.09009009009009017
# 9 1.11 -0.09009009009009017

# %%
returns = [1.0, 1.01, 1.05, 1.1, 1.11, 1.07, 1.13, 1.03, 1.01, 1.02]

tmp_max = 0.0 
max_dd = 0.0

for i in range(1, len(returns)):
    tmp_max = max(tmp_max, returns[i-1])
    max_dd = min(max_dd, returns[i]/tmp_max - 1)
    print(i, tmp_max, abs(max_dd))
# Out:
# 1 1.0 0.0
# 2 1.01 0.0
# 3 1.05 0.0
# 4 1.1 0.0
# 5 1.11 0.03603603603603611
# 6 1.11 0.03603603603603611
# 7 1.13 0.08849557522123885
# 8 1.13 0.10619469026548667
# 9 1.13 0.10619469026548667
