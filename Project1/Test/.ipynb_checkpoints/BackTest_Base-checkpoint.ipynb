# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("ALL.csv")
SPY = pd.read_csv("D:\\NYU\Syllabus\Spring 2020\Quant Equity Invest\Project\Original Data\SPY_Return.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
df.head(3)
# Out:
#    PERMNO        Date TICKER    Price    Return  Shares Outstanding  Turnover  \
# 0   10051  1999-01-01    HGR  22.5000  0.111111             18179.0  0.701029
# 1   10051  1999-02-01    HGR  25.0000 -0.392500             18179.0  0.526817
# 2   10051  1999-03-01    HGR  15.1875 -0.111111             18179.0  1.615710
#
#    Dollar Turnover  Cash Ratio  Current Ratio  Quick Ratio  Revenue Growth  \
# 0        15.773145    1.203904     377.339426   375.233868        0.040000
# 1        13.170416    1.203904     377.339426   375.233868        0.040000
# 2        24.538602    1.203904     377.339426   375.233868        0.054699
#
#    COGS Growth  Gross Income Growth  Operating Income Growth  \
# 0     0.030781             0.049071                 0.085278
# 1     0.030781             0.049071                 0.085278
# 2     0.016057             0.092060                 0.088484
#
#    Net Income Growth  EPS Basic Growth  Net Operating Cash Flow Growth
# 0           0.138436          0.043478                        0.593825
# 1           0.138436          0.043478                        0.593825
# 2           0.069417          0.000000                        0.329531

# %%
SPY.head(3)
# Out:
#          Date    Return
# 0  1995-01-01  0.012817
# 1  1995-02-01  0.024591
# 2  1995-03-01  0.032419

# %%
print(df.shape)
print(SPY.shape)
# Out:
# (348233, 18)
# (252, 2)

# %% [markdown]
# # Explore Correlation

# %% [markdown]
# ## Liquidity Correlation

# %%
df.iloc[:, 6:11].corr()
# Out:
#                  Turnover  Dollar Turnover  Cash Ratio  Current Ratio  \
# Turnover         1.000000         0.144955    0.015613      -0.002352
# Dollar Turnover  0.144955         1.000000    0.005040      -0.000427
# Cash Ratio       0.015613         0.005040    1.000000       0.310998
# Current Ratio   -0.002352        -0.000427    0.310998       1.000000
# Quick Ratio     -0.004524        -0.000896    0.096261       0.962870
#
#                  Quick Ratio
# Turnover           -0.004524
# Dollar Turnover    -0.000896
# Cash Ratio          0.096261
# Current Ratio       0.962870
# Quick Ratio         1.000000

# %% [markdown]
# ## Growth Correlation

# %%
df.iloc[:, 11:].corr()
# Out:
#                                 Revenue Growth  COGS Growth  \
# Revenue Growth                        1.000000     0.039906
# COGS Growth                           0.039906     1.000000
# Gross Income Growth                  -0.000864    -0.006917
# Operating Income Growth               0.000788     0.002965
# Net Income Growth                     0.000021     0.017378
# EPS Basic Growth                     -0.000489    -0.019811
# Net Operating Cash Flow Growth        0.002379    -0.000307
#
#                                 Gross Income Growth  Operating Income Growth  \
# Revenue Growth                            -0.000864                 0.000788
# COGS Growth                               -0.006917                 0.002965
# Gross Income Growth                        1.000000                 0.164942
# Operating Income Growth                    0.164942                 1.000000
# Net Income Growth                         -0.013155                -0.012623
# EPS Basic Growth                          -0.011929                -0.005925
# Net Operating Cash Flow Growth            -0.000033                -0.000190
#
#                                 Net Income Growth  EPS Basic Growth  \
# Revenue Growth                           0.000021         -0.000489
# COGS Growth                              0.017378         -0.019811
# Gross Income Growth                     -0.013155         -0.011929
# Operating Income Growth                 -0.012623         -0.005925
# Net Income Growth                        1.000000          0.188168
# EPS Basic Growth                         0.188168          1.000000
# Net Operating Cash Flow Growth          -0.000771         -0.002139
#
#                                 Net Operating Cash Flow Growth
# Revenue Growth                                        0.002379
# COGS Growth                                          -0.000307
# Gross Income Growth                                  -0.000033
# Operating Income Growth                              -0.000190
# Net Income Growth                                    -0.000771
# EPS Basic Growth                                     -0.002139
# Net Operating Cash Flow Growth                        1.000000

# %% [markdown]
# # Run Regression

# %%
import statsmodels.api as sm
df_ = df.copy()
df_.dropna(inplace=True)
cols = list(df.columns[6:])
X = df_.copy()[cols]
X = sm.add_constant(X)
y = df_.copy()['Return']

Model = sm.OLS(y, X)
Result = Model.fit()
print(Result.summary())
# Out:
# D:\Anaconda\Setup\lib\site-packages\numpy\core\fromnumeric.py:2542: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     15.10
# Date:                Wed, 11 Mar 2020   Prob (F-statistic):           2.55e-32
# Time:                        14:30:24   Log-Likelihood:             1.5785e+05
# No. Observations:              213800   AIC:                        -3.157e+05
# Df Residuals:                  213787   BIC:                        -3.155e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              0.0137      0.000     41.494      0.000       0.013       0.014
# Turnover                           0.0004      0.000      2.129      0.033    3.07e-05       0.001
# Dollar Turnover                -3.313e-05   3.09e-06    -10.715      0.000   -3.92e-05   -2.71e-05
# Cash Ratio                     -4.209e-07   3.22e-06     -0.131      0.896   -6.74e-06     5.9e-06
# Current Ratio                   1.797e-06   2.56e-06      0.702      0.483   -3.22e-06    6.81e-06
# Quick Ratio                    -1.738e-06   2.61e-06     -0.665      0.506   -6.86e-06    3.38e-06
# Revenue Growth                 -1.161e-05      0.000     -0.051      0.959      -0.000       0.000
# COGS Growth                        0.0016      0.000      4.947      0.000       0.001       0.002
# Gross Income Growth             8.776e-06   3.01e-05      0.291      0.771   -5.03e-05    6.79e-05
# Operating Income Growth         2.022e-06   7.11e-06      0.285      0.776   -1.19e-05     1.6e-05
# Net Income Growth              -8.489e-06   6.57e-06     -1.293      0.196   -2.14e-05    4.38e-06
# EPS Basic Growth               -6.375e-05   1.92e-05     -3.329      0.001      -0.000   -2.62e-05
# Net Operating Cash Flow Growth -5.086e-07   6.42e-07     -0.792      0.428   -1.77e-06     7.5e-07
# ==============================================================================
# Omnibus:                    95682.931   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4709726.682
# Skew:                           1.409   Prob(JB):                         0.00
# Kurtosis:                      25.820   Cond. No.                     2.51e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.51e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# From Regression Table, We can initially know that:
# "Turnover", "COGS Growth" have significant positive impact on Return
# "Dollar Turnover", "Assets Growth", "EPS Basic Growth" have significant negative impact on Return

# %% [markdown]
# # Rank for factor

# %% [markdown]
# ## Date Processing

# %%
# Transform Date into datetime type
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

SPY['Date'] = pd.to_datetime(SPY['Date'])
SPY.set_index('Date', inplace=True)

# %%
# Construct Date List
Date = []
for i in range(1995, 2016):
    for j in range(1, 13):
        date = str(i) + '-' + str(j)
        Date.append(date)
        
Date = Date[1:]

# %% [markdown]
# ## Define Rank Function and Use it to rank for each factor

# %%
def percentile_to_score(value):
    if value >= 0.9: value = 1
    elif value >= 0.8: value = 2
    elif value >= 0.7: value = 3
    elif value >= 0.6: value = 4
    elif value >= 0.5: value = 5
    elif value >= 0.4: value = 6
    elif value >= 0.3: value = 7
    elif value >= 0.2: value = 8
    elif value >= 0.1: value = 9
    elif value >= 0.0: value = 10
    return value 

def Rank(df_, factor, factor_rank, Date):
    df = df_.copy()
        
    # First, we select the first date's dataframe and rank
    dataframe = df[Date[0]].copy()
#     dataframe = dataframe.sort_values(by = [factor], axis = 0, ascending = False)  # Sort by Turnover
#     dataframe[factor_rank] = range(len(dataframe))  
#     dataframe[factor_rank] += 1 
    dataframe[factor_rank] = dataframe[factor].rank(pct=True).apply(lambda x: percentile_to_score(x))
    
    for i in range(1, len(Date)):
        DF = df[Date[i]].copy()  # Divide the big df into small DF by date
#         DF = DF.sort_values(by = [factor], axis = 0, ascending = False)  # Sort by Turnover
#         DF[factor_rank] = range(len(DF))  
#         DF[factor_rank] += 1 
        DF[factor_rank] = DF[factor].rank(pct=True).apply(lambda x: percentile_to_score(x))
        dataframe = pd.concat([dataframe, DF])
    
    return dataframe

# %%
Factor_List = list(df.columns[5:])
Factor_Rank = []

for factor in Factor_List:
    factor_rank = factor + " Rank"
    Factor_Rank.append(factor_rank)
    df = Rank(df, factor, factor_rank, Date)   # Rank for each factor

# %%
df.head(3)
# Out:
#             PERMNO TICKER   Price    Return  Shares Outstanding  Turnover  \
# Date
# 1995-02-01   10866     BG  31.875  0.011765             17966.0  0.295224
# 1995-02-01   12008     DY   4.125 -0.060606              8529.0  1.949467
# 1995-02-01   12503    NAV     NaN -0.049180                 NaN  0.651139
#
#             Dollar Turnover  Cash Ratio  Current Ratio  Quick Ratio  \
# Date
# 1995-02-01         9.410275    0.009573       1.069687     0.906763
# 1995-02-01         8.041549    0.002043       0.028833     0.026506
# 1995-02-01         9.929869    0.325770       2.706713     2.259486
#
#             Revenue Growth  COGS Growth  Gross Income Growth  \
# Date
# 1995-02-01        0.152788     0.166768             0.126905
# 1995-02-01        0.142443     0.065801             0.633263
# 1995-02-01             NaN          NaN                  NaN
#
#             Operating Income Growth  Net Income Growth  EPS Basic Growth  \
# Date
# 1995-02-01                      0.0           1.110335          0.976744
# 1995-02-01                    123.5          -1.289012         -1.289474
# 1995-02-01                      NaN                NaN               NaN
#
#             Net Operating Cash Flow Growth  Turnover Rank  \
# Date
# 1995-02-01                       -0.037188              7
# 1995-02-01                       -0.470847              1
# 1995-02-01                             NaN              4
#
#             Dollar Turnover Rank  Cash Ratio Rank  Current Ratio Rank  \
# Date
# 1995-02-01                     5              6.0                 3.0
# 1995-02-01                     5              8.0                 7.0
# 1995-02-01                     4              2.0                 2.0
#
#             Quick Ratio Rank  Revenue Growth Rank  COGS Growth Rank  \
# Date
# 1995-02-01               2.0                  3.0               3.0
# 1995-02-01               6.0                  4.0               5.0
# 1995-02-01               2.0                  NaN               NaN
#
#             Gross Income Growth Rank  Operating Income Growth Rank  \
# Date
# 1995-02-01                       4.0                           7.0
# 1995-02-01                       1.0                           1.0
# 1995-02-01                       NaN                           NaN
#
#             Net Income Growth Rank  EPS Basic Growth Rank  \
# Date
# 1995-02-01                     2.0                    2.0
# 1995-02-01                     9.0                   10.0
# 1995-02-01                     NaN                    NaN
#
#             Net Operating Cash Flow Growth Rank
# Date
# 1995-02-01                                  6.0
# 1995-02-01                                  7.0
# 1995-02-01                                  NaN

# %%
#df_ = df.copy()
for factor in Factor_List:
    #del df_[factor]
    del df[factor]
    
df.head(3)
# Out:
#             PERMNO TICKER   Price    Return  Shares Outstanding  \
# Date
# 1995-02-01   10866     BG  31.875  0.011765             17966.0
# 1995-02-01   12008     DY   4.125 -0.060606              8529.0
# 1995-02-01   12503    NAV     NaN -0.049180                 NaN
#
#             Turnover Rank  Dollar Turnover Rank  Cash Ratio Rank  \
# Date
# 1995-02-01              7                     5              6.0
# 1995-02-01              1                     5              8.0
# 1995-02-01              4                     4              2.0
#
#             Current Ratio Rank  Quick Ratio Rank  Revenue Growth Rank  \
# Date
# 1995-02-01                 3.0               2.0                  3.0
# 1995-02-01                 7.0               6.0                  4.0
# 1995-02-01                 2.0               2.0                  NaN
#
#             COGS Growth Rank  Gross Income Growth Rank  \
# Date
# 1995-02-01               3.0                       4.0
# 1995-02-01               5.0                       1.0
# 1995-02-01               NaN                       NaN
#
#             Operating Income Growth Rank  Net Income Growth Rank  \
# Date
# 1995-02-01                           7.0                     2.0
# 1995-02-01                           1.0                     9.0
# 1995-02-01                           NaN                     NaN
#
#             EPS Basic Growth Rank  Net Operating Cash Flow Growth Rank
# Date
# 1995-02-01                    2.0                                  6.0
# 1995-02-01                   10.0                                  7.0
# 1995-02-01                    NaN                                  NaN

# %% [markdown]
# # Select Stocks based on Rank

# %%
class Solve():
    def __init__(self, df, SPY, Date, Factor_Rank):
        self.df = df
        self.SPY = SPY
        self.Date = Date
        self.Factor_Rank = Factor_Rank
               
    def Get_Returns(self):
        self.df_ = self.df.copy()
        self.Returns = {} # Used to store each factor's return for each month
        self.Excesses = {} # Used to store each factor's return for each excess month
           
        for factor in self.Factor_Rank:
            Return = []  # Used to store return for each month
            Excess = []  # Used to store excess return for each month
            for date in Date:
                DF = self.df_[date].copy()  # Divide the big df into small DF by date
                N = int(len(DF)/10)   # We decide to long top 10% of universe and short bottom 10%
                DF = DF.sort_values(by = [factor], axis = 0, ascending = True)  # Sort by Turnover
                #profit = ( DF.iloc[:N]['Return'].mean() - DF.iloc[-N:]['Return'].mean() ) / 2 
                profit = DF.iloc[int(0.1*N):int(1.1*N)]['Return'].mean()
                #profit = DF.iloc[-N:]['Return'].mean()
                profit_SPY = self.SPY[date]['Return'].values[0]

                Return.append( profit )
                Excess.append( profit - profit_SPY )

            self.Returns[factor] = Return 
            self.Excesses[factor] = Excess

    def Return_Summary(self):
        print("Summary for SPY Return:"); print(self.SPY['Return'].describe())
        print("=============++++++++++++++=============")
        
        for key in self.Factor_Rank:
            print("=============" + key + "=============")
            print("Summary for Return:"); print(pd.Series(self.Returns[key]).describe(), "\n")
            print("Summary for Excess Return:"); print(pd.Series(self.Excesses[key]).describe())
            print("=============++++++++++++++=============")
        
    def T_Test(self):
        from scipy import stats
        print("==============================++++++++++++++==============================")
        for factor in self.Factor_Rank:
            print("Result of T Test for " + factor + ":")
            print(stats.ttest_1samp(self.Excesses[factor], 0))
            print("==============================++++++++++++++==============================")
            
    def Plot_hist_Return(self):
        plt.figure(figsize=(15,3))
        count = 0
        
        for key in self.Factor_Rank:
            count += 1
            ax = plt.subplot(13,2,count)
            plt.hist(self.Returns[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of Return from' + key)
            
            count += 1
            ax = plt.subplot(13,2,count)
            plt.hist(self.Excesses[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of Excess Return from' + key)


    def Plot_Cum_Return(self):
        fig1 = plt.figure(figsize = (20, 10))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Returns[factor])+1).cumprod()-1, label = factor) 
            
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Returns for each Factor',fontsize =15)
        
        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]
        
        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)
        
    def Plot_Cum_Excess(self):

        fig1 = plt.figure(figsize = (20, 10))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY', color = 'black') 

        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Excesses[factor])+1).cumprod()-1, label = factor) 
 
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Returns for each Factor',fontsize =15)

        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]

        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)

# %%
Object = Solve(df, SPY, Date, Factor_Rank)

# %% [markdown]
# ## Calculate Returns and Excess Returns

# %%
Object.Get_Returns()

# %% [markdown]
# ## Give a Summary for all Factors' Return and Excess

# %%
Object.Return_Summary()
# Out:
# Summary for SPY Return:
# count    252.000000
# mean       0.007206
# std        0.046654
# min       -0.167743
# 25%       -0.019238
# 50%        0.012929
# 75%        0.034528
# max        0.157330
# Name: Return, dtype: float64
# =============++++++++++++++=============
# =============Turnover Rank=============
# Summary for Return:
# count    251.000000
# mean       0.013693
# std        0.073416
# min       -0.245008
# 25%       -0.026230
# 50%        0.014007
# 75%        0.056944
# max        0.436256
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.006509
# std        0.081600
# min       -0.274857
# 25%       -0.045991
# 50%        0.003641
# 75%        0.048740
# max        0.303159
# dtype: float64
# =============++++++++++++++=============
# =============Dollar Turnover Rank=============
# Summary for Return:
# count    251.000000
# mean       0.009109
# std        0.053577
# min       -0.248792
# 25%       -0.020440
# 50%        0.013628
# 75%        0.046477
# max        0.154830
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.001926
# std        0.065461
# min       -0.249300
# 25%       -0.037938
# 50%        0.004615
# 75%        0.035557
# max        0.242167
# dtype: float64
# =============++++++++++++++=============
# =============Cash Ratio Rank=============
# Summary for Return:
# count    251.000000
# mean       0.011178
# std        0.050194
# min       -0.196183
# 25%       -0.019217
# 50%        0.017286
# 75%        0.038970
# max        0.177367
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.003994
# std        0.063407
# min       -0.251867
# 25%       -0.035293
# 50%        0.002926
# 75%        0.037382
# max        0.265502
# dtype: float64
# =============++++++++++++++=============
# =============Current Ratio Rank=============
# Summary for Return:
# count    251.000000
# mean       0.012044
# std        0.050627
# min       -0.232340
# 25%       -0.014027
# 50%        0.015122
# 75%        0.041046
# max        0.257165
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.004861
# std        0.062552
# min       -0.229044
# 25%       -0.031573
# 50%        0.002661
# 75%        0.037123
# max        0.257510
# dtype: float64
# =============++++++++++++++=============
# =============Quick Ratio Rank=============
# Summary for Return:
# count    251.000000
# mean       0.012738
# std        0.051327
# min       -0.235488
# 25%       -0.012344
# 50%        0.015349
# 75%        0.043398
# max        0.247918
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.005554
# std        0.062533
# min       -0.237648
# 25%       -0.032818
# 50%        0.003316
# 75%        0.039507
# max        0.243195
# dtype: float64
# =============++++++++++++++=============
# =============Revenue Growth Rank=============
# Summary for Return:
# count    251.000000
# mean       0.013151
# std        0.051299
# min       -0.224796
# 25%       -0.011147
# 50%        0.013371
# 75%        0.043556
# max        0.211191
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.005968
# std        0.062617
# min       -0.202538
# 25%       -0.030921
# 50%        0.002459
# 75%        0.038826
# max        0.274753
# dtype: float64
# =============++++++++++++++=============
# =============COGS Growth Rank=============
# Summary for Return:
# count    251.000000
# mean       0.012839
# std        0.051880
# min       -0.247370
# 25%       -0.013732
# 50%        0.014926
# 75%        0.045563
# max        0.213808
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.005655
# std        0.063175
# min       -0.198055
# 25%       -0.035707
# 50%        0.007278
# 75%        0.036614
# max        0.257473
# dtype: float64
# =============++++++++++++++=============
# =============Gross Income Growth Rank=============
# Summary for Return:
# count    251.000000
# mean       0.014987
# std        0.052206
# min       -0.255678
# 25%       -0.010716
# 50%        0.017433
# 75%        0.044305
# max        0.216885
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.007803
# std        0.062731
# min       -0.199059
# 25%       -0.032245
# 50%        0.004340
# 75%        0.044235
# max        0.278359
# dtype: float64
# =============++++++++++++++=============
# =============Operating Income Growth Rank=============
# Summary for Return:
# count    251.000000
# mean       0.014919
# std        0.053888
# min       -0.251515
# 25%       -0.010651
# 50%        0.016351
# 75%        0.046847
# max        0.246916
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.007735
# std        0.064271
# min       -0.225371
# 25%       -0.032744
# 50%        0.004944
# 75%        0.042570
# max        0.274591
# dtype: float64
# =============++++++++++++++=============
# =============Net Income Growth Rank=============
# Summary for Return:
# count    251.000000
# mean       0.014365
# std        0.054283
# min       -0.245297
# 25%       -0.010935
# 50%        0.017390
# 75%        0.044601
# max        0.318663
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.007181
# std        0.063950
# min       -0.221473
# 25%       -0.034534
# 50%        0.009139
# 75%        0.041965
# max        0.285571
# dtype: float64
# =============++++++++++++++=============
# =============EPS Basic Growth Rank=============
# Summary for Return:
# count    251.000000
# mean       0.014140
# std        0.053773
# min       -0.241624
# 25%       -0.010116
# 50%        0.016360
# 75%        0.044503
# max        0.313824
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.006956
# std        0.063898
# min       -0.230711
# 25%       -0.033129
# 50%        0.007310
# 75%        0.041004
# max        0.252138
# dtype: float64
# =============++++++++++++++=============
# =============Net Operating Cash Flow Growth Rank=============
# Summary for Return:
# count    251.000000
# mean       0.013827
# std        0.053938
# min       -0.197823
# 25%       -0.013458
# 50%        0.016763
# 75%        0.043239
# max        0.273960
# dtype: float64
#
# Summary for Excess Return:
# count    251.000000
# mean       0.006643
# std        0.065525
# min       -0.236289
# 25%       -0.032751
# 50%        0.002743
# 75%        0.041431
# max        0.265516
# dtype: float64
# =============++++++++++++++=============

# %%
Object.T_Test()
# Out:
# ==============================++++++++++++++==============================
# Result of T Test for Turnover Rank:
# Ttest_1sampResult(statistic=1.263744950212952, pvalue=0.20749870655588315)
# ==============================++++++++++++++==============================
# Result of T Test for Dollar Turnover Rank:
# Ttest_1sampResult(statistic=0.4660833110114603, pvalue=0.6415616985267534)
# ==============================++++++++++++++==============================
# Result of T Test for Cash Ratio Rank:
# Ttest_1sampResult(statistic=0.9979660530792822, pvalue=0.3192607671325959)
# ==============================++++++++++++++==============================
# Result of T Test for Current Ratio Rank:
# Ttest_1sampResult(statistic=1.2311230531824684, pvalue=0.21943376891611638)
# ==============================++++++++++++++==============================
# Result of T Test for Quick Ratio Rank:
# Ttest_1sampResult(statistic=1.4071184233758691, pvalue=0.16063427585953474)
# ==============================++++++++++++++==============================
# Result of T Test for Revenue Growth Rank:
# Ttest_1sampResult(statistic=1.5099320111933778, pvalue=0.13232360931706602)
# ==============================++++++++++++++==============================
# Result of T Test for COGS Growth Rank:
# Ttest_1sampResult(statistic=1.4182223784645918, pvalue=0.15737116044981284)
# ==============================++++++++++++++==============================
# Result of T Test for Gross Income Growth Rank:
# Ttest_1sampResult(statistic=1.9707678898406933, pvalue=0.049853638405382254)
# ==============================++++++++++++++==============================
# Result of T Test for Operating Income Growth Rank:
# Ttest_1sampResult(statistic=1.9067706724755222, pvalue=0.057696672460266454)
# ==============================++++++++++++++==============================
# Result of T Test for Net Income Growth Rank:
# Ttest_1sampResult(statistic=1.7790644483282887, pvalue=0.07644417813539259)
# ==============================++++++++++++++==============================
# Result of T Test for EPS Basic Growth Rank:
# Ttest_1sampResult(statistic=1.7246459144448316, pvalue=0.08582727567580706)
# ==============================++++++++++++++==============================
# Result of T Test for Net Operating Cash Flow Growth Rank:
# Ttest_1sampResult(statistic=1.6062127217807531, pvalue=0.10948949979117224)
# ==============================++++++++++++++==============================

# %% [markdown]
# ## Plot Cumulative Return for each Factor

# %%
Object.Plot_Cum_Return()

# %%
Object.Plot_Cum_Excess()

# %% [markdown]
# # Combine Factors

# %%
class Combine():
    def __init__(self, df, SPY, Date):
        self.df = df
        self.SPY = SPY
        self.Date = Date
        
    def Combine_Factors(self):
        self.data = self.df.copy()
        self.data['Liquid Ratio Rank'] = (self.data['Cash Ratio Rank'] + self.data['Current Ratio Rank'] + self.data['Quick Ratio Rank']) / 3 
        self.data['Turnover Combine Rank'] = (self.data['Turnover Rank'] + self.data['Dollar Turnover Rank']) / 2
        self.data['Income Combine Rank'] = (self.data['COGS Growth Rank'] + self.data['Operating Income Growth Rank'] + self.data['Net Income Growth Rank']) / 3
        
        self.data['Total Rank'] = (self.data['Revenue Growth Rank'] + self.data['Income Combine Rank'] +
                                   self.data['EPS Basic Growth Rank'] + self.data['Net Operating Cash Flow Growth Rank'] + self.data['Liquid Ratio Rank'] +
                                   self.data['Income Combine Rank']) / 6
               
    def Get_Returns(self):
        self.data_ = self.data.copy()
           
        self.Return = []  # Used to store return for each month
        self.Excess = []  # Used to store excess return for each month
        for date in Date:
            DF = self.data_[date].copy()  # Divide the big df into small DF by date
            N = int(len(DF)/10)   # We decide to long top 10% of universe and short bottom 10%
            DF = DF.sort_values(by = ['Total Rank'], axis = 0, ascending = True)  # Sort by Turnover
            #profit = ( DF.iloc[:N]['Return'].mean() - DF.iloc[-N:]['Return'].mean() ) / 2 
            profit = DF.iloc[int(0.1*N):int(1.1*N)]['Return'].mean()
            #profit = DF.iloc[-N:]['Return'].mean()
            profit_SPY = self.SPY[date]['Return'].values[0]

            self.Return.append( profit )
            self.Excess.append( profit - profit_SPY )

    def Return_Summary(self):
        print("=============++++++++++++++=============")
        print("Summary for SPY Return:"); print(self.SPY['Return'].describe())
        print("=============++++++++++++++=============")
        print("Summary for Return:")
        print(pd.Series(self.Return).describe())
        print("=============++++++++++++++=============")
        print("Summary for Excess Return:")
        print(pd.Series(self.Excess).describe())
        print("=============++++++++++++++=============")
        
    def T_Test(self):
        from scipy import stats
        print("==============================++++++++++++++==============================")
        print("Result of T Test")
        print(stats.ttest_1samp(self.Excess, 0))
        print("==============================++++++++++++++==============================")
            
    def Plot_hist_Return(self):
        plt.figure(figsize=(15,4))
        ax1 = plt.subplot(1,3,1)
        plt.hist(self.Return, bins=20)
        plt.ylabel('Frequency')
        plt.title('Distribution of Return')
            
        ax2 = plt.subplot(1,3,2)
        plt.hist(self.Excess, bins=20)
        plt.ylabel('Frequency')
        plt.title('Distribution of Excess Return') 
        
        ax3 = plt.subplot(1,3,3)
        plt.hist(self.SPY['Return'].values, bins=20)
        plt.ylabel('Frequency')
        plt.title('Distribution of SPY Return') 

    def Plot_Cum_Return(self):
        fig1 = plt.figure(figsize = (15, 6))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'].iloc[1:] + 1).cumprod()-1, label = 'SPY Return')
        
        plt.plot(self.Date, (pd.Series(self.Return)+1).cumprod()-1, label = 'Return')   
        plt.plot(self.Date, (pd.Series(self.Excess)+1).cumprod()-1, label = 'Excess Return') 
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Return for Combine Factor',fontsize =15)
        
        ax1.legend(loc=2)

# %%
Object2 = Combine(df, SPY, Date)

# %% [markdown]
# ## Combine All these Factors into one

# %%
Object2.Combine_Factors()

# %% [markdown]
# ## Calculate Return

# %%
Object2.Get_Returns()

# %% [markdown]
# ## Give a Summary for Return and T Test for Excess Return

# %%
Object2.Return_Summary()
# Out:
# =============++++++++++++++=============
# Summary for SPY Return:
# count    252.000000
# mean       0.007206
# std        0.046654
# min       -0.167743
# 25%       -0.019238
# 50%        0.012929
# 75%        0.034528
# max        0.157330
# Name: Return, dtype: float64
# =============++++++++++++++=============
# Summary for Return:
# count    251.000000
# mean       0.013503
# std        0.048840
# min       -0.227461
# 25%       -0.008963
# 50%        0.017345
# 75%        0.043695
# max        0.211050
# dtype: float64
# =============++++++++++++++=============
# Summary for Excess Return:
# count    251.000000
# mean       0.006320
# std        0.060254
# min       -0.198733
# 25%       -0.029144
# 50%        0.005132
# 75%        0.038883
# max        0.271323
# dtype: float64
# =============++++++++++++++=============

# %%
Object2.T_Test()
# Out:
# ==============================++++++++++++++==============================
# Result of T Test
# Ttest_1sampResult(statistic=1.6616293817088676, pvalue=0.09784052224341971)
# ==============================++++++++++++++==============================

# %% [markdown]
# ## Plot Cumulative Return

# %%
Object2.Plot_hist_Return()

# %%
Object2.Plot_Cum_Return()
