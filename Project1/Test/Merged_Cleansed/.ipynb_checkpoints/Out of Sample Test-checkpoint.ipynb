# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("OutofSample.csv")
SPY = pd.read_csv("SPY_test.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
df.head(3)
# Out:
#    PERMNO        Date TICKER  Price    Return  Share Outstanding   Turnover  \
# 0   10051  2015-12-01    HGR  16.45  0.056519               35291  0.970899
# 1   10051  2016-01-01    HGR  13.49 -0.179939               35291  1.144994
# 2   10051  2018-10-01   HNGR  18.66 -0.104177               36799  0.693253
#
#    Dollar Turnover  Current Ratio  Cash Ratio  Quick Ratio  Revenue Growth  \
# 0        15.971290       1.641972     0.28752      1.32757        0.008599
# 1        15.445975       1.641972     0.28752      1.32757        0.008599
# 2        12.936092       1.641972     0.28752      1.32757        0.008599
#
#    COGS Growth  Operating Income Growth  Net Income Growth  EPS Basic Growth  \
# 0     0.020741                -0.109413           0.940769         -0.590909
# 1     0.020741                -0.109413           0.940769         -0.590909
# 2     0.020741                -0.109413           0.940769         -0.590909
#
#    Net Operating Cash Flow Growth
# 0                             0.0
# 1                             0.0
# 2                             0.0

# %%
SPY.head(3)
# Out:
#          Date    Return
# 0  2016-01-01 -0.050735
# 1  2016-02-01 -0.004128
# 2  2016-03-01  0.065991

# %%
print(df.shape)
print(SPY.shape)
# Out:
# (69651, 17)
# (48, 2)

# %% [markdown]
# # Explore Correlation

# %% [markdown]
# ## Liquidity Correlation

# %%
df.iloc[:, 6:11].corr()
# Out:
#                  Turnover  Dollar Turnover  Current Ratio  Cash Ratio  \
# Turnover         1.000000         0.434245      -0.007201   -0.001199
# Dollar Turnover  0.434245         1.000000      -0.002034   -0.004193
# Current Ratio   -0.007201        -0.002034       1.000000    0.295894
# Cash Ratio      -0.001199        -0.004193       0.295894    1.000000
# Quick Ratio     -0.012086        -0.000462       0.906629    0.298606
#
#                  Quick Ratio
# Turnover           -0.012086
# Dollar Turnover    -0.000462
# Current Ratio       0.906629
# Cash Ratio          0.298606
# Quick Ratio         1.000000

# %% [markdown]
# ## Growth Correlation

# %%
df.iloc[:, 11:].corr()
# Out:
#                                 Revenue Growth  COGS Growth  \
# Revenue Growth                        1.000000     0.024905
# COGS Growth                           0.024905     1.000000
# Operating Income Growth              -0.002496    -0.008474
# Net Income Growth                    -0.002551    -0.049512
# EPS Basic Growth                     -0.001126    -0.002983
# Net Operating Cash Flow Growth       -0.000640     0.000283
#
#                                 Operating Income Growth  Net Income Growth  \
# Revenue Growth                                -0.002496          -0.002551
# COGS Growth                                   -0.008474          -0.049512
# Operating Income Growth                        1.000000          -0.002124
# Net Income Growth                             -0.002124           1.000000
# EPS Basic Growth                              -0.000492           0.059696
# Net Operating Cash Flow Growth                 0.000584          -0.000273
#
#                                 EPS Basic Growth  \
# Revenue Growth                         -0.001126
# COGS Growth                            -0.002983
# Operating Income Growth                -0.000492
# Net Income Growth                       0.059696
# EPS Basic Growth                        1.000000
# Net Operating Cash Flow Growth         -0.000440
#
#                                 Net Operating Cash Flow Growth
# Revenue Growth                                       -0.000640
# COGS Growth                                           0.000283
# Operating Income Growth                               0.000584
# Net Income Growth                                    -0.000273
# EPS Basic Growth                                     -0.000440
# Net Operating Cash Flow Growth                        1.000000

# %% [markdown]
# # Run Regression

# %%
import statsmodels.api as sm
df_ = df.copy()
df_.dropna(inplace=True)
cols = list(df.columns[6:])
X = df_.copy()[cols]
X = sm.add_constant(X)
y = df_.copy()['Return']

Model = sm.OLS(y, X)
Result = Model.fit()
print(Result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     10.03
# Date:                Wed, 11 Mar 2020   Prob (F-statistic):           1.63e-18
# Time:                        16:47:39   Log-Likelihood:                 49757.
# No. Observations:               69651   AIC:                        -9.949e+04
# Df Residuals:                   69639   BIC:                        -9.938e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              0.0069      0.001      9.417      0.000       0.005       0.008
# Turnover                        6.128e-05      0.000      0.524      0.600      -0.000       0.000
# Dollar Turnover                 2.508e-05   2.82e-06      8.903      0.000    1.96e-05    3.06e-05
# Current Ratio                      0.0002      0.001      0.369      0.712      -0.001       0.001
# Cash Ratio                       4.35e-05   9.66e-05      0.450      0.652      -0.000       0.000
# Quick Ratio                        0.0001      0.001      0.245      0.806      -0.001       0.001
# Revenue Growth                     0.0001   8.43e-05      1.320      0.187   -5.39e-05       0.000
# COGS Growth                    -6.782e-05      0.000     -0.272      0.785      -0.001       0.000
# Operating Income Growth          5.64e-05   4.22e-05      1.337      0.181   -2.63e-05       0.000
# Net Income Growth              -4.685e-06   1.02e-05     -0.460      0.646   -2.47e-05    1.53e-05
# EPS Basic Growth                4.869e-06   6.25e-06      0.779      0.436   -7.38e-06    1.71e-05
# Net Operating Cash Flow Growth  1.426e-05   1.93e-05      0.737      0.461   -2.36e-05    5.22e-05
# ==============================================================================
# Omnibus:                    19654.484   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           316374.497
# Skew:                           0.930   Prob(JB):                         0.00
# Kurtosis:                      13.274   Cond. No.                         402.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# D:\Anaconda\Setup\lib\site-packages\numpy\core\fromnumeric.py:2542: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# From Regression Table, We can initially know that:
# "Turnover", "COGS Growth" have significant positive impact on Return
# "Dollar Turnover", "EPS Basic Growth" have significant negative impact on Return

# %% [markdown]
# # Rank for factor

# %% [markdown]
# ## Date Processing

# %%
# Transform Date into datetime type
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

SPY['Date'] = pd.to_datetime(SPY['Date'])
SPY.set_index('Date', inplace=True)

# %%
# Construct Date List
Date = []
for i in range(2016, 2020):
    for j in range(1, 13):
        date = str(i) + '-' + str(j)
        Date.append(date)
        
#Date = Date[1:]

# %% [markdown]
# ## Define Rank Function and Use it to rank for each factor

# %%
def percentile_to_score(value):
    if value >= 0.9: value = 1
    elif value >= 0.8: value = 2
    elif value >= 0.7: value = 3
    elif value >= 0.6: value = 4
    elif value >= 0.5: value = 5
    elif value >= 0.4: value = 6
    elif value >= 0.3: value = 7
    elif value >= 0.2: value = 8
    elif value >= 0.1: value = 9
    elif value >= 0.0: value = 10
    return value 

def Rank(df_, factor, factor_rank, Date):
    df = df_.copy()
        
    # First, we select the first date's dataframe and rank
    dataframe = df[Date[0]].copy()
#     dataframe = dataframe.sort_values(by = [factor], axis = 0, ascending = False)  # Sort by Turnover
#     dataframe[factor_rank] = range(len(dataframe))  
#     dataframe[factor_rank] += 1 
    dataframe[factor_rank] = dataframe[factor].rank(pct=True).apply(lambda x: percentile_to_score(x))
    
    for i in range(1, len(Date)):
        DF = df[Date[i]].copy()  # Divide the big df into small DF by date
#         DF = DF.sort_values(by = [factor], axis = 0, ascending = False)  # Sort by Turnover
#         DF[factor_rank] = range(len(DF))  
#         DF[factor_rank] += 1 
        DF[factor_rank] = DF[factor].rank(pct=True).apply(lambda x: percentile_to_score(x))
        dataframe = pd.concat([dataframe, DF])
    
    return dataframe

# %%
Factor_List = list(df.columns[5:])
Factor_Rank = []

for factor in Factor_List:
    factor_rank = factor + " Rank"
    Factor_Rank.append(factor_rank)
    df = Rank(df, factor, factor_rank, Date)   # Rank for each factor

# %%
df.head(3)
# Out:
#             PERMNO TICKER   Price    Return  Share Outstanding   Turnover  \
# Date
# 2016-01-01   10051    HGR   13.49 -0.179939               35291  1.144994
# 2016-01-01   10145    HON  103.20 -0.003572              770691  0.934442
# 2016-01-01   10147    EMC   24.77 -0.035436             1943000  1.660859
#
#             Dollar Turnover  Current Ratio  Cash Ratio  Quick Ratio  \
# Date
# 2016-01-01        15.445975       1.641972    0.287520     1.327570
# 2016-01-01        96.434409       1.091557    0.296935     0.850961
# 2016-01-01        41.139490       1.169034    0.719829     1.072410
#
#             Revenue Growth  COGS Growth  Operating Income Growth  \
# Date
# 2016-01-01        0.008599     0.020741                -0.109413
# 2016-01-01       -0.016777    -0.026251                 0.015911
# 2016-01-01        0.000988    -0.022773                -0.009288
#
#             Net Income Growth  EPS Basic Growth  \
# Date
# 2016-01-01           0.940769         -0.590909
# 2016-01-01           0.058626          0.065789
# 2016-01-01          -0.014374          0.000000
#
#             Net Operating Cash Flow Growth  Turnover Rank  \
# Date
# 2016-01-01                        0.000000              8
# 2016-01-01                        0.910880              9
# 2016-01-01                        0.663985              6
#
#             Dollar Turnover Rank  Current Ratio Rank  Cash Ratio Rank  \
# Date
# 2016-01-01                     8                   5                6
# 2016-01-01                     3                   8                6
# 2016-01-01                     6                   8                4
#
#             Quick Ratio Rank  Revenue Growth Rank  COGS Growth Rank  \
# Date
# 2016-01-01                 5                    5                 4
# 2016-01-01                 8                    6                 7
# 2016-01-01                 6                    5                 7
#
#             Operating Income Growth Rank  Net Income Growth Rank  \
# Date
# 2016-01-01                             8                       2
# 2016-01-01                             5                       4
# 2016-01-01                             6                       5
#
#             EPS Basic Growth Rank  Net Operating Cash Flow Growth Rank
# Date
# 2016-01-01                      8                                    9
# 2016-01-01                      4                                    3
# 2016-01-01                      5                                    4

# %%
#df_ = df.copy()
for factor in Factor_List:
    #del df_[factor]
    del df[factor]
    
df.head(3)
# Out:
#             PERMNO TICKER   Price    Return  Share Outstanding   \
# Date
# 2016-01-01   10051    HGR   13.49 -0.179939               35291
# 2016-01-01   10145    HON  103.20 -0.003572              770691
# 2016-01-01   10147    EMC   24.77 -0.035436             1943000
#
#             Turnover Rank  Dollar Turnover Rank  Current Ratio Rank  \
# Date
# 2016-01-01              8                     8                   5
# 2016-01-01              9                     3                   8
# 2016-01-01              6                     6                   8
#
#             Cash Ratio Rank  Quick Ratio Rank  Revenue Growth Rank  \
# Date
# 2016-01-01                6                 5                    5
# 2016-01-01                6                 8                    6
# 2016-01-01                4                 6                    5
#
#             COGS Growth Rank  Operating Income Growth Rank  \
# Date
# 2016-01-01                 4                             8
# 2016-01-01                 7                             5
# 2016-01-01                 7                             6
#
#             Net Income Growth Rank  EPS Basic Growth Rank  \
# Date
# 2016-01-01                       2                      8
# 2016-01-01                       4                      4
# 2016-01-01                       5                      5
#
#             Net Operating Cash Flow Growth Rank
# Date
# 2016-01-01                                    9
# 2016-01-01                                    3
# 2016-01-01                                    4

# %% [markdown]
# # Select Stocks based on Rank

# %%
class Solve():
    def __init__(self, df, SPY, Date, Factor_Rank):
        self.df = df
        self.SPY = SPY
        self.Date = Date
        self.Factor_Rank = Factor_Rank
               
    def Get_Returns(self):
        self.df_ = self.df.copy()
        self.Returns = {} # Used to store each factor's return for each month
        self.Excesses = {} # Used to store each factor's return for each excess month
           
        for factor in self.Factor_Rank:
            Return = []  # Used to store return for each month
            Excess = []  # Used to store excess return for each month
            for date in Date:
                DF = self.df_[date].copy()  # Divide the big df into small DF by date
                N = int(len(DF)/10)   # We decide to long top 10% of universe and short bottom 10%
                DF = DF.sort_values(by = [factor], axis = 0, ascending = True)  # Sort by Turnover
                #profit = ( DF.iloc[:N]['Return'].mean() - DF.iloc[-N:]['Return'].mean() ) / 2 
                profit = DF.iloc[int(0.1*N):int(1.1*N)]['Return'].mean()
                #profit = DF.iloc[-N:]['Return'].mean()
                profit_SPY = self.SPY[date]['Return'].values[0]

                Return.append( profit )
                Excess.append( profit - profit_SPY )

            self.Returns[factor] = Return 
            self.Excesses[factor] = Excess

    def Return_Summary(self):
        print("Summary for SPY Return:"); print(self.SPY['Return'].describe())
        print("=============++++++++++++++=============")
        
        for key in self.Factor_Rank:
            print("=============" + key + "=============")
            print("Summary for Return:"); print(pd.Series(self.Returns[key]).describe(), "\n")
            print("Summary for Excess Return:"); print(pd.Series(self.Excesses[key]).describe())
            print("=============++++++++++++++=============")
        
    def T_Test(self):
        from scipy import stats
        print("==============================++++++++++++++==============================")
        for factor in self.Factor_Rank:
            print("Result of T Test for " + factor + ":")
            print(stats.ttest_1samp(self.Excesses[factor], 0))
            print("==============================++++++++++++++==============================")
            
    def Plot_hist_Return(self):
        plt.figure(figsize=(15,3))
        count = 0
        
        for key in self.Factor_Rank:
            count += 1
            ax = plt.subplot(13,2,count)
            plt.hist(self.Returns[key], bins=8)
            plt.ylabel('Frequency')
            plt.title('Distribution of Return from' + key)
            
            count += 1
            ax = plt.subplot(13,2,count)
            plt.hist(self.Excesses[key], bins=20)
            plt.ylabel('Frequency')
            plt.title('Distribution of Excess Return from' + key)


    def Plot_Cum_Return(self):
        fig1 = plt.figure(figsize = (10, 4))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'] + 1).cumprod()-1, label = 'SPY', color = 'black')
        
        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Returns[factor])+1).cumprod()-1, label = factor) 
            
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Returns for each Factor',fontsize =15)
        
        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]
        
        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)
        
    def Plot_Cum_Excess(self):

        fig1 = plt.figure(figsize = (10, 4))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'] + 1).cumprod()-1, label = 'SPY', color = 'black') 

        for factor in self.Factor_Rank:
            plt.plot(self.Date, (pd.Series(self.Excesses[factor])+1).cumprod()-1, label = factor) 
 
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Returns for each Factor',fontsize =15)

        colormap = plt.cm.gist_ncar
        colors = [colormap(i) for i in np.linspace(0, 1,len(ax1.lines))]

        for i,j in enumerate(ax1.lines):
            j.set_color(colors[i])
        ax1.legend(loc=2)

# %%
Object = Solve(df, SPY, Date, Factor_Rank)

# %% [markdown]
# ## Calculate Returns and Excess Returns

# %%
Object.Get_Returns()

# %% [markdown]
# ## Give a Summary for all Factors' Return and Excess

# %%
Object.Return_Summary()
# Out:
# Summary for SPY Return:
# count    48.000000
# mean      0.010139
# std       0.033477
# min      -0.091777
# 25%       0.000313
# 50%       0.016253
# 75%       0.029862
# max       0.078684
# Name: Return, dtype: float64
# =============++++++++++++++=============
# =============Turnover Rank=============
# Summary for Return:
# count    48.000000
# mean      0.013681
# std       0.076230
# min      -0.157774
# 25%      -0.031842
# 50%       0.014740
# 75%       0.056373
# max       0.198447
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.003543
# std       0.055554
# min      -0.091996
# 25%      -0.042520
# 50%      -0.003041
# 75%       0.035420
# max       0.153020
# dtype: float64
# =============++++++++++++++=============
# =============Dollar Turnover Rank=============
# Summary for Return:
# count    48.000000
# mean      0.023568
# std       0.045114
# min      -0.100522
# 25%       0.009155
# 50%       0.023232
# 75%       0.049277
# max       0.128252
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.013429
# std       0.020778
# min      -0.026066
# 25%      -0.002405
# 50%       0.008713
# 75%       0.029451
# max       0.054302
# dtype: float64
# =============++++++++++++++=============
# =============Current Ratio Rank=============
# Summary for Return:
# count    48.000000
# mean      0.011982
# std       0.047931
# min      -0.110342
# 25%      -0.005548
# 50%       0.012018
# 75%       0.035552
# max       0.128447
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.001843
# std       0.030089
# min      -0.050664
# 25%      -0.021431
# 50%      -0.001462
# 75%       0.023761
# max       0.069534
# dtype: float64
# =============++++++++++++++=============
# =============Cash Ratio Rank=============
# Summary for Return:
# count    48.000000
# mean      0.013731
# std       0.045858
# min      -0.101350
# 25%       0.000348
# 50%       0.013792
# 75%       0.039705
# max       0.118249
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.003592
# std       0.027131
# min      -0.045606
# 25%      -0.015650
# 50%       0.003227
# 75%       0.023721
# max       0.089171
# dtype: float64
# =============++++++++++++++=============
# =============Quick Ratio Rank=============
# Summary for Return:
# count    48.000000
# mean      0.011076
# std       0.046922
# min      -0.096281
# 25%      -0.003840
# 50%       0.015509
# 75%       0.035931
# max       0.127248
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.000937
# std       0.027951
# min      -0.051278
# 25%      -0.016404
# 50%      -0.003420
# 75%       0.021205
# max       0.067568
# dtype: float64
# =============++++++++++++++=============
# =============Revenue Growth Rank=============
# Summary for Return:
# count    48.000000
# mean      0.011063
# std       0.046781
# min      -0.116146
# 25%      -0.010867
# 50%       0.018500
# 75%       0.031121
# max       0.136121
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.000924
# std       0.026640
# min      -0.050819
# 25%      -0.015906
# 50%      -0.003809
# 75%       0.023120
# max       0.057437
# dtype: float64
# =============++++++++++++++=============
# =============COGS Growth Rank=============
# Summary for Return:
# count    48.000000
# mean      0.011806
# std       0.051512
# min      -0.111487
# 25%      -0.004832
# 50%       0.015167
# 75%       0.036183
# max       0.148548
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.001668
# std       0.032811
# min      -0.061115
# 25%      -0.020295
# 50%      -0.002104
# 75%       0.018185
# max       0.112511
# dtype: float64
# =============++++++++++++++=============
# =============Operating Income Growth Rank=============
# Summary for Return:
# count    48.000000
# mean      0.011378
# std       0.050282
# min      -0.112201
# 25%      -0.008348
# 50%       0.013347
# 75%       0.035164
# max       0.142072
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.001239
# std       0.031284
# min      -0.050800
# 25%      -0.020553
# 50%      -0.008268
# 75%       0.022536
# max       0.074992
# dtype: float64
# =============++++++++++++++=============
# =============Net Income Growth Rank=============
# Summary for Return:
# count    48.000000
# mean      0.012709
# std       0.053461
# min      -0.118217
# 25%      -0.003819
# 50%       0.012610
# 75%       0.029619
# max       0.141313
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.002570
# std       0.033897
# min      -0.046879
# 25%      -0.016566
# 50%      -0.002973
# 75%       0.015236
# max       0.133093
# dtype: float64
# =============++++++++++++++=============
# =============EPS Basic Growth Rank=============
# Summary for Return:
# count    48.000000
# mean      0.013617
# std       0.053652
# min      -0.121060
# 25%      -0.008082
# 50%       0.017068
# 75%       0.038203
# max       0.149176
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.003479
# std       0.034382
# min      -0.046599
# 25%      -0.019744
# 50%      -0.002959
# 75%       0.021064
# max       0.130326
# dtype: float64
# =============++++++++++++++=============
# =============Net Operating Cash Flow Growth Rank=============
# Summary for Return:
# count    48.000000
# mean      0.010745
# std       0.048851
# min      -0.129029
# 25%      -0.005194
# 50%       0.011949
# 75%       0.033338
# max       0.141932
# dtype: float64
#
# Summary for Excess Return:
# count    48.000000
# mean      0.000607
# std       0.026037
# min      -0.038706
# 25%      -0.018994
# 50%      -0.003445
# 75%       0.013574
# max       0.063247
# dtype: float64
# =============++++++++++++++=============

# %%
Object.T_Test()
# Out:
# ==============================++++++++++++++==============================
# Result of T Test for Turnover Rank:
# Ttest_1sampResult(statistic=0.44180449568826763, pvalue=0.6606568592958284)
# ==============================++++++++++++++==============================
# Result of T Test for Dollar Turnover Rank:
# Ttest_1sampResult(statistic=4.47780956144566, pvalue=4.79425518032544e-05)
# ==============================++++++++++++++==============================
# Result of T Test for Current Ratio Rank:
# Ttest_1sampResult(statistic=0.42434673279160595, pvalue=0.6732491155742255)
# ==============================++++++++++++++==============================
# Result of T Test for Cash Ratio Rank:
# Ttest_1sampResult(statistic=0.9173485933812567, pvalue=0.36364353191189813)
# ==============================++++++++++++++==============================
# Result of T Test for Quick Ratio Rank:
# Ttest_1sampResult(statistic=0.23225407229857, pvalue=0.8173490434681338)
# ==============================++++++++++++++==============================
# Result of T Test for Revenue Growth Rank:
# Ttest_1sampResult(statistic=0.24035355161015753, pvalue=0.8111014884148481)
# ==============================++++++++++++++==============================
# Result of T Test for COGS Growth Rank:
# Ttest_1sampResult(statistic=0.35215100769368235, pvalue=0.726299175211742)
# ==============================++++++++++++++==============================
# Result of T Test for Operating Income Growth Rank:
# Ttest_1sampResult(statistic=0.2744033052274949, pvalue=0.7849772341140248)
# ==============================++++++++++++++==============================
# Result of T Test for Net Income Growth Rank:
# Ttest_1sampResult(statistic=0.5253507843437595, pvalue=0.6018091423281674)
# ==============================++++++++++++++==============================
# Result of T Test for EPS Basic Growth Rank:
# Ttest_1sampResult(statistic=0.7009445746327735, pvalue=0.48679359470735883)
# ==============================++++++++++++++==============================
# Result of T Test for Net Operating Cash Flow Growth Rank:
# Ttest_1sampResult(statistic=0.1614216602995467, pvalue=0.8724532175348501)
# ==============================++++++++++++++==============================

# %% [markdown]
# ## Plot Cumulative Return for each Factor

# %%
Object.Plot_Cum_Return()

# %%
Object.Plot_Cum_Excess()

# %% [markdown]
# # Combine Factors

# %%
class Combine():
    def __init__(self, df, SPY, Date):
        self.df = df
        self.SPY = SPY
        self.Date = Date
        
    def Combine_Factors(self):
        self.data = self.df.copy()
        self.data['Liquid Ratio Rank'] = (self.data['Cash Ratio Rank'] + self.data['Current Ratio Rank'] + self.data['Quick Ratio Rank']) / 3 
        self.data['Turnover Combine Rank'] = (self.data['Turnover Rank'] + self.data['Dollar Turnover Rank']) / 2
        self.data['Income Combine Rank'] = (self.data['COGS Growth Rank'] + self.data['Operating Income Growth Rank'] + self.data['Net Income Growth Rank']) / 3
        
        self.data['Total Rank'] = (self.data['Revenue Growth Rank'] + self.data['Income Combine Rank'] +
                                   self.data['EPS Basic Growth Rank'] + self.data['Net Operating Cash Flow Growth Rank'] + self.data['Liquid Ratio Rank'] +
                                   self.data['Income Combine Rank']) / 6
               
    def Get_Returns(self):
        self.data_ = self.data.copy()
           
        self.Return = []  # Used to store return for each month
        self.Excess = []  # Used to store excess return for each month
        for date in Date:
            DF = self.data_[date].copy()  # Divide the big df into small DF by date
            N = int(len(DF)/10)   # We decide to long top 10% of universe and short bottom 10%
            DF = DF.sort_values(by = ['Total Rank'], axis = 0, ascending = True)  # Sort by Turnover
            #profit = ( DF.iloc[:N]['Return'].mean() - DF.iloc[-N:]['Return'].mean() ) / 2 
            profit = DF.iloc[int(0.1*N):int(1.1*N)]['Return'].mean()
            #profit = DF.iloc[-N:]['Return'].mean()
            profit_SPY = self.SPY[date]['Return'].values[0]

            self.Return.append( profit )
            self.Excess.append( profit - profit_SPY )

    def Return_Summary(self):
        print("=============++++++++++++++=============")
        print("Summary for SPY Return:"); print(self.SPY['Return'].describe())
        print("=============++++++++++++++=============")
        print("Summary for Return:")
        print(pd.Series(self.Return).describe())
        print("=============++++++++++++++=============")
        print("Summary for Excess Return:")
        print(pd.Series(self.Excess).describe())
        print("=============++++++++++++++=============")
        
    def T_Test(self):
        from scipy import stats
        print("==============================++++++++++++++==============================")
        print("Result of T Test")
        print(stats.ttest_1samp(self.Excess, 0))
        print("==============================++++++++++++++==============================")
            
    def Plot_hist_Return(self):
        plt.figure(figsize=(12,4))
        ax1 = plt.subplot(1,3,1)
        plt.hist(self.Return, bins=5)
        plt.ylabel('Frequency')
        plt.title('Distribution of Return')
            
        ax2 = plt.subplot(1,3,2)
        plt.hist(self.Excess, bins=5)
        plt.ylabel('Frequency')
        plt.title('Distribution of Excess Return') 
        
        ax3 = plt.subplot(1,3,3)
        plt.hist(self.SPY['Return'].values, bins=5)
        plt.ylabel('Frequency')
        plt.title('Distribution of SPY Return') 

    def Plot_Cum_Return(self):
        fig1 = plt.figure(figsize = (12, 4))
        ax1 = fig1.add_subplot(111)
        
        plt.plot(self.Date, (self.SPY['Return'] + 1).cumprod()-1, label = 'SPY Return')
        
        plt.plot(self.Date, (pd.Series(self.Return)+1).cumprod()-1, label = 'Return')   
        plt.plot(self.Date, (pd.Series(self.Excess)+1).cumprod()-1, label = 'Excess Return') 
        plt.tick_params(axis='x', which='major', labelsize=15)
        plt.tick_params(axis='y', which='major', labelsize=15)
        plt.xticks(np.arange(0, len(Date), step=12))
        plt.ylabel('Cumulative Return', fontsize = 15)
        locs, labels = plt.xticks() 
        plt.setp(labels, rotation = 90)
        plt.title('Cumulative Return for Combine Factor',fontsize =15)
        
        ax1.legend(loc=2)

# %%
Object2 = Combine(df, SPY, Date)

# %% [markdown]
# ## Combine All these Factors into one

# %%
Object2.Combine_Factors()

# %% [markdown]
# ## Calculate Return

# %%
Object2.Get_Returns()

# %% [markdown]
# ## Give a Summary for Return and T Test for Excess Return

# %%
Object2.Return_Summary()
# Out:
# =============++++++++++++++=============
# Summary for SPY Return:
# count    48.000000
# mean      0.010139
# std       0.033477
# min      -0.091777
# 25%       0.000313
# 50%       0.016253
# 75%       0.029862
# max       0.078684
# Name: Return, dtype: float64
# =============++++++++++++++=============
# Summary for Return:
# count    48.000000
# mean      0.012643
# std       0.043398
# min      -0.098121
# 25%      -0.002120
# 50%       0.018052
# 75%       0.034465
# max       0.116702
# dtype: float64
# =============++++++++++++++=============
# Summary for Excess Return:
# count    48.000000
# mean      0.002504
# std       0.021604
# min      -0.036142
# 25%      -0.015523
# 50%      -0.000879
# 75%       0.016708
# max       0.046445
# dtype: float64
# =============++++++++++++++=============

# %%
Object2.T_Test()
# Out:
# ==============================++++++++++++++==============================
# Result of T Test
# Ttest_1sampResult(statistic=0.8029778324494451, pvalue=0.4260296872385324)
# ==============================++++++++++++++==============================

# %% [markdown]
# ## Plot Cumulative Return

# %%
Object2.Plot_hist_Return()

# %%
Object2.Plot_Cum_Return()
