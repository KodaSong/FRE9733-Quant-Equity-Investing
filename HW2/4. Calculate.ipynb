# %% [markdown]
# # Import Packages

# %%
import factor_tester as ft
import numpy as np
import pandas as pd 
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("./Data/Fast.csv")

# %% [markdown]
# The Universe is S&P500

# %% [markdown]
# BackTest Period: 2019-03-01 -> 2020-02-28; Use Data Period: 2018-03-01 -> 2019-02-28
# Trading Period: 2020-03-02 -> 2020-03-31; Use Data Period: 2019-03-01 -> 2020-02-28

# %%
df.head(3)
# Out:
#          Date Ticker       Close    Return    1W   1M   3M   6M   SPY Close  \
# 0  2018-03-01    MMM  231.339996 -0.017706   7.0  8.0  7.0  4.0  267.700012
# 1  2018-03-01    AOS   62.060001 -0.033183  10.0  6.0  6.0  4.0  267.700012
# 2  2018-03-01    ABT   58.790001 -0.025526   4.0  6.0  4.0  3.0  267.700012
#
#    SPY Return        Rf      Beta     Alpha  1W + 1M  1W + 3M  1W + 6M  \
# 0   -0.014541  0.000081  1.074155 -0.524473      7.5      7.0      5.5
# 1   -0.014541  0.000081  1.153893 -4.130742      8.0      8.0      7.0
# 2   -0.014541  0.000081  0.911332 -3.095087      5.0      4.0      3.5
#
#    1M + 3M  1M + 6M  3M + 6M  1W + 1M + 3M  1W + 1M + 6M  1W + 3M + 6M  \
# 0      7.5      6.0      5.5      7.333333      6.333333      6.000000
# 1      6.0      5.0      5.0      7.333333      6.666667      6.666667
# 2      5.0      4.5      3.5      4.666667      4.333333      3.666667
#
#    1M + 3M + 6M  Total Rank
# 0      6.333333        6.50
# 1      5.333333        6.50
# 2      4.333333        4.25

# %% [markdown]
# Factors are Momentum: 1-Week, 1-Month, 3-Month, 6-Month
# Combine Factors: 1 Week + 1 Month (average), etc.

# %%
Factors = ['1W', '1M', '3M', '6M', 
           '1W + 1M', '1W + 3M', '1W + 6M', '1M + 3M', '1M + 6M', '3M + 6M',
           '1W + 1M + 3M', '1W + 1M + 6M', '1W + 3M + 6M', '1M + 3M + 6M',
           'Total Rank']

# %%
Tickers = list(set(df['Ticker'].values))
Date1 = '2019-02-28'
Date2 = '2020-02-28'  # '2020-02-29' is not trading day
Date3 = '2020-03-31'

# %% [markdown]
# # BackTesting

# %%
BT = ft.BackTest(df, Factors, 'BackTest')

# %%
BT.Construct_DF(Tickers, Date1, Date2)

# %%
N = 7

# %% [markdown]
# ## Show BackTesting Portfolio

# %% [markdown]
# **<font color = red size = 3>Selection Criteria</font>**

# %% [markdown]
# Every Stock has a series of daily ranks on each Factor;
# Take the average of these ranks
# e.g. AAPL 1-Week Momentum Average Rank is 7.33;

# %% [markdown]
# For each factor, select the highest 7 stocks and put into Top List and put lowest 7 stocks into Bottom List;
# Then I gather all the stocks and collect their **<font color = red size = 3>Frequency</font>**

# %% [markdown]
# Select 2 stocks which appear most in Top List -> Long stock1 and stock2;
# Select 2 stocks which appear most in Bottom List -> Short stock1 and stock2

# %%
BT.Select_Stock_List(N)
BT.Determine_Stock()

# %% [markdown]
# **<font color = red size = 3>Optimize</font>**

# %% [markdown]
# Each Side on Long and Short has $25e6
# Optimize 2 stocks on Long side and 2 stocks on Short side
# Minimize each side variance

# %%
BT.Show_Portfolio()
BT.Portfolio_Info
# Out:
#     Side 1st Stock  1st Weight 2nd Stock  2nd Weight
# 0   Long      VRSN    0.351041       AES    0.648920
# 1  Short       AMG    0.574647       IVZ    0.425236

# %%
BT.Cal_PnL()

# %% [markdown]
# ## Show PnL & Return DataFrame

# %%
BT.PnL.head(3)
# Out:
#                 Daily PnL     Net Value  Daily Return  SPY Daily  \
# Date
# 2019-03-01       0.000000  5.000000e+07      0.000000   0.000000
# 2019-03-04 -467243.428074  4.953276e+07     -0.009345  -0.003637
# 2019-03-05  522185.210190  5.005494e+07      0.010444  -0.001360
#
#             Net Value Level  SPY Level
# Date
# 2019-03-01         1.000000   1.000000
# 2019-03-04         0.990655   0.996363
# 2019-03-05         1.001099   0.995002

# %%
BT.PnL.tail(3)
# Out:
#                 Daily PnL     Net Value  Daily Return  SPY Daily  \
# Date
# 2020-02-26 -230353.146666  5.780320e+07     -0.004607  -0.003678
# 2020-02-27   21521.752965  5.782472e+07      0.000430  -0.044912
# 2020-02-28 -718260.856548  5.710646e+07     -0.014365  -0.004202
#
#             Net Value Level  SPY Level
# Date
# 2020-02-26         1.156064   1.113332
# 2020-02-27         1.156494   1.068421
# 2020-02-28         1.142129   1.064219

# %% [markdown]
# ## Portfolio Risk Characteristics

# %%
BT.Summarize('d')
# Out:
# Summary Statistics (Return):
# count    250.000000
# mean       0.000569
# std        0.007968
# min       -0.026890
# 25%       -0.004366
# 50%        0.001278
# 75%        0.004963
# max        0.034520
# Name: Daily Return, dtype: float64
# --------------------------------------------
# Summary Statistics (PnL):
# count    2.500000e+02
# mean     2.842583e+04
# std      3.984165e+05
# min     -1.344518e+06
# 25%     -2.182867e+05
# 50%      6.387704e+04
# 75%      2.481495e+05
# max      1.726014e+06
# Name: Daily PnL, dtype: float64
# --------------------------------------------
# Summary Statistics (Annualized Return):
# Mean:  0.143266164885648
# Vol: 0.1262400818803466
# t-statistics:  1.1348706587614474 ;  p-value:  0.25752078932524897
# --------------------------------------------
# Total PnL:  7106456.59155
# Final Wealth:  57106456.59155
# --------------------------------------------
# Information Ratio: 0.39
# --------------------------------------------
# Maximum DrawDown: 6.99%
# --------------------------------------------
# VaR at 95% Level: $626911.02

# %% [markdown]
# ## Plot Time Series

# %%
BT.Plot_Return()
# Out:
# D:\Anaconda\Setup\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # PaperTrading in March 2020

# %%
TD = ft.Trade(df, Factors, 'Trade')

# %%
TD.Construct_DF(Tickers, Date1, Date2, Date3)

# %%
TD.Select_Stock_List(N) # N = 7

# %% [markdown]
# ## Show Paper Trading Portfolio

# %%
TD.Determine_Stock()
TD.Show_Portfolio()
TD.Portfolio_Info
# Out:
#     Side 1st Stock  1st Weight 2nd Stock  2nd Weight
# 0   Long       GPN    0.524382       MCO    0.475012
# 1  Short       MAC    0.895765       RRC    0.104193

# %%
TD.Cal_PnL()

# %% [markdown]
# ## Show 1-Month Daily PnL & Return DataFrame

# %%
TD.PnL
# Out:
#                Daily PnL     Net Value  Daily Return  SPY Daily  \
# Date
# 2020-03-02  0.000000e+00  5.000000e+07      0.000000   0.000000
# 2020-03-03 -8.877276e+05  4.911227e+07     -0.017755  -0.028632
# 2020-03-04  3.561435e+05  4.946842e+07      0.007123   0.042033
# 2020-03-05 -1.057107e+05  4.936271e+07     -0.002114  -0.033242
# 2020-03-06 -1.656012e+05  4.919710e+07     -0.003312  -0.016531
# 2020-03-09  1.252318e+06  5.044942e+07      0.025046  -0.078094
# 2020-03-10  9.797666e+05  5.142919e+07      0.019595   0.051745
# 2020-03-11  1.158863e+06  5.258805e+07      0.023177  -0.048748
# 2020-03-12 -8.009104e+04  5.250796e+07     -0.001602  -0.095677
# 2020-03-13  1.482267e+06  5.399023e+07      0.029645   0.085486
# 2020-03-16  7.031396e+05  5.469337e+07      0.014063  -0.109424
# 2020-03-17  1.674465e+06  5.636783e+07      0.033489   0.053992
# 2020-03-18  6.755116e+05  5.704334e+07      0.013510  -0.050633
# 2020-03-19 -1.468692e+06  5.557465e+07     -0.029374   0.002125
# 2020-03-20 -5.267811e+05  5.504787e+07     -0.010536  -0.048688
# 2020-03-23  2.197036e+05  5.526758e+07      0.004394  -0.025568
# 2020-03-24  2.106883e+06  5.737446e+07      0.042138   0.090603
# 2020-03-25  1.120512e+06  5.849497e+07      0.022410   0.014970
# 2020-03-26  2.327118e+06  6.082209e+07      0.046542   0.058390
# 2020-03-27  2.027160e+05  6.102480e+07      0.004054  -0.029786
# 2020-03-30  5.482759e+05  6.157308e+07      0.010966   0.032476
# 2020-03-31 -4.991220e+05  6.107396e+07     -0.009982  -0.014905
#
#             Net Value Level  SPY Level
# Date
# 2020-03-02         1.000000   1.000000
# 2020-03-03         0.982245   0.971368
# 2020-03-04         0.989368   1.013401
# 2020-03-05         0.987254   0.980159
# 2020-03-06         0.983942   0.963628
# 2020-03-09         1.008988   0.885533
# 2020-03-10         1.028584   0.937278
# 2020-03-11         1.051761   0.888530
# 2020-03-12         1.050159   0.792853
# 2020-03-13         1.079805   0.878339
# 2020-03-16         1.093867   0.768915
# 2020-03-17         1.127357   0.822907
# 2020-03-18         1.140867   0.772274
# 2020-03-19         1.111493   0.774399
# 2020-03-20         1.100957   0.725711
# 2020-03-23         1.105352   0.700143
# 2020-03-24         1.147489   0.790746
# 2020-03-25         1.169899   0.805716
# 2020-03-26         1.216442   0.864106
# 2020-03-27         1.220496   0.834320
# 2020-03-30         1.231462   0.866796
# 2020-03-31         1.221479   0.851891

# %% [markdown]
# ## Plot Time Series

# %%
TD.Plot_Return()

# %%
a = TD.Trading_df.copy()
r1 = a[a.Ticker == 'GPN']['Return'][1:]
r2 = a[a.Ticker == 'MCO']['Return'][1:]
r3 = a[a.Ticker == 'MAC']['Return'][1:]
r4 = a[a.Ticker == 'RRC']['Return'][1:]
r = a[a.Ticker == 'GPN']['SPY Return'][1:]

# %%
plt.figure(figsize=(12,6))
# plt.plot(((r1+1).cumprod()) * 0.524)
# plt.plot(((r2+1).cumprod()) * 0.476)
# plt.plot(((r3+1).cumprod()) * 0.896)
# plt.plot(((r4+1).cumprod()) * 0.104)
plt.plot(((r1+1).cumprod()))
plt.plot(((r2+1).cumprod()))
plt.plot(((r3+1).cumprod()))
plt.plot(((r4+1).cumprod()))
plt.plot((r+1).cumprod())
plt.legend(['GPN (L 52.4%)', 'MCO (L 47.6%)', 'MAC (S 89.6%)', 'RRC (S 10.4%)', 'SPY'])
plt.show()

# %%
a = BT.BackTest_df.copy()
r1 = a[a.Ticker == 'VRSN']['Return'][1:]
r2 = a[a.Ticker == 'AES']['Return'][1:]
r3 = a[a.Ticker == 'AMG']['Return'][1:]
r4 = a[a.Ticker == 'IVZ']['Return'][1:]
r = a[a.Ticker == 'VRSN']['SPY Return'][1:]

# %%
plt.figure(figsize=(12,6))
plt.plot(((r1+1).cumprod()))
plt.plot(((r2+1).cumprod()))
plt.plot(((r3+1).cumprod()))
plt.plot(((r4+1).cumprod()))
plt.plot((r+1).cumprod())
plt.legend(['VRSN (L 35.1%)', 'AES (L 64.9%)', 'AMG (S 57.5%)', 'IVZ (S 42.5%)', 'SPY'])
plt.show()
