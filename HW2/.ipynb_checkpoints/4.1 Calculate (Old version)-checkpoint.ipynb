# %% [markdown]
# # Import Packages

# %%
import test_helper as th
import numpy as np
import pandas as pd 
import Statistics
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("./Data/Fast.csv")

# %% [markdown]
# The Universe is S&P500

# %% [markdown]
# BackTest Period: 2019-03-01 -> 2020-02-28; Use Data Period: 2018-03-01 -> 2019-02-28
# Trading Period: 2020-03-02 -> 2020-03-31; Use Data Period: 2019-03-01 -> 2020-02-28

# %%
df.head(3)
# Out:
#          Date Ticker       Close    Return    1W   1M   3M   6M   SPY Close  \
# 0  2018-03-01    MMM  231.339996 -0.017706   7.0  8.0  7.0  4.0  267.700012
# 1  2018-03-01    AOS   62.060001 -0.033183  10.0  6.0  6.0  4.0  267.700012
# 2  2018-03-01    ABT   58.790001 -0.025526   4.0  6.0  4.0  3.0  267.700012
#
#    SPY Return        Rf      Beta     Alpha  1W + 1M  1W + 3M  1W + 6M  \
# 0   -0.014541  0.000081  1.074155 -0.524473      7.5      7.0      5.5
# 1   -0.014541  0.000081  1.153893 -4.130742      8.0      8.0      7.0
# 2   -0.014541  0.000081  0.911332 -3.095087      5.0      4.0      3.5
#
#    1M + 3M  1M + 6M  3M + 6M  1W + 1M + 3M  1W + 1M + 6M  1W + 3M + 6M  \
# 0      7.5      6.0      5.5      7.333333      6.333333      6.000000
# 1      6.0      5.0      5.0      7.333333      6.666667      6.666667
# 2      5.0      4.5      3.5      4.666667      4.333333      3.666667
#
#    1M + 3M + 6M  Total Rank
# 0      6.333333        6.50
# 1      5.333333        6.50
# 2      4.333333        4.25

# %% [markdown]
# Factors are Momentum: 1-Week, 1-Month, 3-Month, 6-Month
# Combine Factors: 1 Week + 1 Month (average), etc.

# %%
Factors = ['1W', '1M', '3M', '6M', 
           '1W + 1M', '1W + 3M', '1W + 6M', '1M + 3M', '1M + 6M', '3M + 6M',
           '1W + 1M + 3M', '1W + 1M + 6M', '1W + 3M + 6M', '1M + 3M + 6M',
           'Total Rank']

# %%
Tickers = list(set(df['Ticker'].values))
Date1 = '2019-02-28'
Date2 = '2020-02-28'  # '2020-02-29' is not trading day
Date3 = '2020-03-31'

# %% [markdown]
# # BackTesting

# %%
Option1 = 'BackTest'
BT = th.BackTest(df, Factors)

# %%
BT.Construct_DF(Tickers, Date1, Date2)

# %%
N = 7

# %% [markdown]
# ## Show BackTesting Pairs

# %% [markdown]
# **<font color = red size = 3>Selection Criteria</font>**

# %% [markdown]
# Every Stock has a series of daily ranks on each Factor;
# Take the average of these ranks
# e.g. AAPL 1-Week Momentum Average Rank is 7.33;

# %% [markdown]
# For each factor, select the highest 7 stocks and put into Top List and put lowest 7 stocks into Bottom List;
# Then I gather all the stocks and collect their **<font color = red size = 3>Frequency</font>**

# %% [markdown]
# Select 2 stocks which appear most in Top List -> Long stock1 and stock2;
# Select 2 stocks which appear most in Bottom List -> Short stock1 and stock2

# %%
BT.Select_Stock_List(N, Option1)
#BT.Select_Stock_List(Option1)
BT.Determine_Stock(Option1)

# %% [markdown]
# **<font color = red size = 3>Optimize</font>**

# %% [markdown]
# Each Side on Long and Short has $25e6
# Optimize 2 stocks on Long side and 2 stocks on Short side
# Minimize each side variance

# %%
BT.Show_Pairs(Option1)
BT.Pair_Information
# Out:
#     Pair  Long  Long_Weight Short  Short_Weight
# 0  Pair1  INTU     0.857197   KHC      0.599067
# 1  Pair2  ILMN     0.141909    LB      0.400766

# %%
BT.Cal_PnL(Option1)

# %% [markdown]
# ## Show PnL & Return DataFrame

# %%
BT.PnL.head(3)
# Out:
#                      PnL1           PnL2  Daily Return1  Cum Return1  \
# Date
# 2019-03-01       0.000000       0.000000       0.000000     1.000000
# 2019-03-04 -504180.396572  103087.407579      -0.013849     0.986151
# 2019-03-05  -75487.954186  -86616.574412      -0.002073     0.984078
#
#             Daily Return2  Cum Return2  Total Daily PnL  Total Daily Return  \
# Date
# 2019-03-01       0.000000     1.000000         0.000000            0.000000
# 2019-03-04       0.007598     1.007598   -401092.988993           -0.008022
# 2019-03-05      -0.006384     1.001214   -162104.528598           -0.003242
#
#             Total Cum Return  Daily SPY   Cum SPY
# Date
# 2019-03-01          1.000000   0.000000  1.000000
# 2019-03-04          0.991978  -0.003637  0.996363
# 2019-03-05          0.988736  -0.001360  0.995002

# %%
BT.PnL.tail(3)
# Out:
#                      PnL1           PnL2  Daily Return1  Cum Return1  \
# Date
# 2020-02-26 -203958.134590  314545.748633      -0.005602     1.155524
# 2020-02-27 -658186.587174 -260830.686265      -0.018079     1.137446
# 2020-02-28 -157219.069480  569517.005477      -0.004318     1.133127
#
#             Daily Return2  Cum Return2  Total Daily PnL  Total Daily Return  \
# Date
# 2020-02-26       0.023185     1.089056    110587.614043            0.002212
# 2020-02-27      -0.019226     1.069831   -919017.273439           -0.018380
# 2020-02-28       0.041978     1.111809    412297.935997            0.008246
#
#             Total Cum Return  Daily SPY   Cum SPY
# Date
# 2020-02-26          1.137407  -0.003678  1.113332
# 2020-02-27          1.119026  -0.044912  1.068421
# 2020-02-28          1.127272  -0.004202  1.064219

# %% [markdown]
# ## Portfolio Risk Characteristics

# %%
Statistics.Summarize(BT.PnL, freq='d')
# Out:
# Summary Statistics (Return):
# count    250.000000
# mean       0.000509
# std        0.010248
# min       -0.041705
# 25%       -0.005342
# 50%        0.000849
# 75%        0.006293
# max        0.040134
# Name: Total Daily Return, dtype: float64
# --------------------------------------------
# Summary Statistics (PnL):
# count    2.500000e+02
# mean     2.545444e+04
# std      5.123969e+05
# min     -2.085237e+06
# 25%     -2.671128e+05
# 50%      4.247097e+04
# 75%      3.146682e+05
# max      2.006717e+06
# Name: Total Daily PnL, dtype: float64
# --------------------------------------------
# Summary Statistics (Annualized Return):
# Mean:  0.12829035707911582
# t-statistics:  0.7901827870223238 ;  p-value:  0.4301729094667025
# --------------------------------------------
# Total PnL:  6363608.982098989
# Final Wealth:  56363608.98209899
# --------------------------------------------
# Information Ratio: 0.34
# --------------------------------------------
# Maximum DrawDown: 11.43%
# --------------------------------------------
# VaR at 95% Level: $817363.50

# %% [markdown]
# ## Plot Time Series

# %%
BT.Plot_Return()
# Out:
# D:\Anaconda\Setup\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Trading in March 2020

# %%
Option2 = 'Trade'
TD = th.Trade(df, Factors)

# %%
TD.Construct_DF(Tickers, Date1, Date2, Date3)

# %%
TD.Select_Stock_List(N, Option2) # N = 7
#TD.Select_Stock_List(Option2) # N = 7

# %% [markdown]
# ## Show Trading Pairs

# %%
TD.Determine_Stock(Option2)
TD.Show_Pairs(Option2)
TD.Pair_Information
# Out:
#     Pair  Long  Long_Weight Short  Short_Weight
# 0  Pair1  CHTR     0.586413   AAL      0.532625
# 1  Pair2   ZTS     0.413257   MRO      0.467309

# %%
TD.Cal_PnL(Option2)

# %% [markdown]
# ## Show 1-Month Daily PnL & Return DataFrame

# %%
TD.PnL
# Out:
#                     PnL1          PnL2  Daily Return1  Cum Return1  \
# Date
# 2020-03-02  0.000000e+00  0.000000e+00       0.000000     1.000000
# 2020-03-03  6.513200e+05  2.401275e+05       0.023281     1.023281
# 2020-03-04  3.375346e+05  4.320096e+05       0.012065     1.035347
# 2020-03-05  1.237559e+06  1.325894e+05       0.044237     1.079583
# 2020-03-06 -1.981279e+05  1.172284e+06      -0.007082     1.072501
# 2020-03-09 -1.238741e+05  3.937941e+06      -0.004428     1.068073
# 2020-03-10 -1.190129e+06 -8.557160e+05      -0.042541     1.025532
# 2020-03-11 -2.451946e+05  2.522131e+05      -0.008764     1.016768
# 2020-03-12  1.304427e+06 -5.881692e+05       0.046627     1.063394
# 2020-03-13  1.763494e+05 -3.840799e+05       0.006304     1.069698
# 2020-03-16 -3.050012e+06 -6.276679e+05      -0.109023     0.960675
# 2020-03-17  3.549942e+05  8.302473e+05       0.012689     0.973364
# 2020-03-18  2.436480e+06 -1.504535e+05       0.087092     1.060456
# 2020-03-19  1.299436e+06 -7.916107e+05       0.046448     1.106905
# 2020-03-20 -6.915237e+05  2.749390e+05      -0.024719     1.082186
# 2020-03-23  3.881317e+05 -3.210359e+05       0.013874     1.096060
# 2020-03-24 -1.484992e+06  4.605219e+05      -0.053081     1.042979
# 2020-03-25 -9.975423e+05  3.726587e+05      -0.035657     1.007322
# 2020-03-26  7.913411e+05  3.004701e+05       0.028286     1.035608
# 2020-03-27  7.183019e+05  4.808566e+04       0.025676     1.061284
# 2020-03-30  1.589492e+06  7.570372e+05       0.056816     1.118100
