# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Monthly Datasets

# %%
months = pd.read_csv('./Data1/1.2.csv')
months.head()
# Out:
#        Date Ticker              Company Name     Cusip     Price    Return  \
# 0  20000131      A  AGILENT TECHNOLOGIES INC  00846U10   66.1875 -0.143897
# 1  20000229      A  AGILENT TECHNOLOGIES INC  00846U10  103.8750  0.569405
# 2  20000331      A  AGILENT TECHNOLOGIES INC  00846U10  104.0000  0.001203
# 3  20000428      A  AGILENT TECHNOLOGIES INC  00846U10   88.6250 -0.147837
# 4  20000531      A  AGILENT TECHNOLOGIES INC  00846U10   73.6250 -0.169252
#
#    Shares Outstanding
# 0            452000.0
# 1            452000.0
# 2            452000.0
# 3            452000.0
# 4            452000.0

# %% [markdown]
# ## Fundamental Datasets

# %%
fundamentals = pd.read_csv("./Data1/2.2.csv")
fundamentals.head()
# Out:
#        Date Ticker      Cusip              Company Name  Total Assets  \
# 0  20000131      A  00846U101  AGILENT TECHNOLOGIES INC        7107.0
# 1  20000430      A  00846U101  AGILENT TECHNOLOGIES INC        7321.0
# 2  20000731      A  00846U101  AGILENT TECHNOLOGIES INC        7827.0
# 3  20001031      A  00846U101  AGILENT TECHNOLOGIES INC        8425.0
# 4  20010131      A  00846U101  AGILENT TECHNOLOGIES INC        9208.0
#
#    Stockholders Equity
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# delete repeated columns
del fundamentals['Cusip']
del fundamentals['Company Name']
# Calculate book-to-equity
fundamentals
# Out:
#            Date Ticker  Total Assets  Stockholders Equity
# 0      20000131      A      7107.000                  NaN
# 1      20000430      A      7321.000                  NaN
# 2      20000731      A      7827.000                  NaN
# 3      20001031      A      8425.000                  NaN
# 4      20010131      A      9208.000                  NaN
# ...         ...    ...           ...                  ...
# 99175  20091130     ZZ      1015.470             -107.992
# 99176  20100228     ZZ      1011.929              -92.278
# 99177  20100531     ZZ       965.401              -88.170
# 99178  20100831     ZZ       964.883              -95.431
# 99179  20101130     ZZ       936.757              -87.639
#
# [99180 rows x 4 columns]

# %% [markdown]
# # Data Processing

# %%
# Keep the date same in order for further matching
# Eliminate "day" -> /100 and transform into integers
months['Date'] = months['Date']/100
fundamentals['Date'] = fundamentals['Date']/100

months['Date'] = months['Date'].astype('int')
fundamentals['Date'] = fundamentals['Date'].astype('int')

# %%
# Set "Ticker" and "date" as index
months.set_index(['Ticker','Date'], inplace = True)
months.head()
# Out:
#                            Company Name     Cusip     Price    Return  \
# Ticker Date
# A      200001  AGILENT TECHNOLOGIES INC  00846U10   66.1875 -0.143897
#        200002  AGILENT TECHNOLOGIES INC  00846U10  103.8750  0.569405
#        200003  AGILENT TECHNOLOGIES INC  00846U10  104.0000  0.001203
#        200004  AGILENT TECHNOLOGIES INC  00846U10   88.6250 -0.147837
#        200005  AGILENT TECHNOLOGIES INC  00846U10   73.6250 -0.169252
#
#                Shares Outstanding
# Ticker Date
# A      200001            452000.0
#        200002            452000.0
#        200003            452000.0
#        200004            452000.0
#        200005            452000.0

# %%
fundamentals.set_index(['Ticker','Date'], inplace = True)
fundamentals.head()
# Out:
#                Total Assets  Stockholders Equity
# Ticker Date
# A      200001        7107.0                  NaN
#        200004        7321.0                  NaN
#        200007        7827.0                  NaN
#        200010        8425.0                  NaN
#        200101        9208.0                  NaN

# %% [markdown]
# ## Merge two datasets based on Ticker and Date

# %%
# Merge two dataframes on two indices
# 'outer' -> union, 'inner' -> intersection
df = pd.merge(months, fundamentals, on = ['Ticker', 'Date'], how = 'outer')

# %%
df
# Out:
#                            Company Name     Cusip     Price    Return  \
# Ticker Date
# A      200001  AGILENT TECHNOLOGIES INC  00846U10   66.1875 -0.143897
#        200002  AGILENT TECHNOLOGIES INC  00846U10  103.8750  0.569405
#        200003  AGILENT TECHNOLOGIES INC  00846U10  104.0000  0.001203
#        200004  AGILENT TECHNOLOGIES INC  00846U10   88.6250 -0.147837
#        200005  AGILENT TECHNOLOGIES INC  00846U10   73.6250 -0.169252
# ...                                 ...       ...       ...       ...
# ZF.1   200912                       NaN       NaN       NaN       NaN
#        201003                       NaN       NaN       NaN       NaN
#        201006                       NaN       NaN       NaN       NaN
#        201009                       NaN       NaN       NaN       NaN
#        201012                       NaN       NaN       NaN       NaN
#
#                Shares Outstanding  Total Assets  Stockholders Equity
# Ticker Date
# A      200001            452000.0        7107.0                  NaN
#        200002            452000.0           NaN                  NaN
#        200003            452000.0           NaN                  NaN
#        200004            452000.0        7321.0                  NaN
#        200005            452000.0           NaN                  NaN
# ...                           ...           ...                  ...
# ZF.1   200912                 NaN           NaN                  NaN
#        201003                 NaN           NaN                  NaN
#        201006                 NaN           NaN                  NaN
#        201009                 NaN           NaN                  NaN
#        201012                 NaN           NaN                  NaN
#
# [368338 rows x 7 columns]

# %% [markdown]
# ## Let's process missing values

# %% [markdown]
# ### First, delete rows without "Company Name"

# %%
df.dropna(axis=0, thresh=5, inplace=True)

# %%
df
# Out:
#                            Company Name     Cusip     Price    Return  \
# Ticker Date
# A      200001  AGILENT TECHNOLOGIES INC  00846U10   66.1875 -0.143897
#        200002  AGILENT TECHNOLOGIES INC  00846U10  103.8750  0.569405
#        200003  AGILENT TECHNOLOGIES INC  00846U10  104.0000  0.001203
#        200004  AGILENT TECHNOLOGIES INC  00846U10   88.6250 -0.147837
#        200005  AGILENT TECHNOLOGIES INC  00846U10   73.6250 -0.169252
# ...                                 ...       ...       ...       ...
# ZZ     201008                SEALY CORP  81213930    2.3700 -0.135037
#        201009                SEALY CORP  81213930    2.4400  0.029536
#        201010                SEALY CORP  81213930    2.6300  0.077869
#        201011                SEALY CORP  81213930    3.0200  0.148289
#        201012                SEALY CORP  81213930    2.9200 -0.033113
#
#                Shares Outstanding  Total Assets  Stockholders Equity
# Ticker Date
# A      200001            452000.0      7107.000                  NaN
#        200002            452000.0           NaN                  NaN
#        200003            452000.0           NaN                  NaN
#        200004            452000.0      7321.000                  NaN
#        200005            452000.0           NaN                  NaN
# ...                           ...           ...                  ...
# ZZ     201008             97520.0       964.883              -95.431
#        201009             97494.0           NaN                  NaN
#        201010             97494.0           NaN                  NaN
#        201011             97494.0       936.757              -87.639
#        201012             97494.0           NaN                  NaN
#
# [338754 rows x 7 columns]

# %% [markdown]
# ### Assets, Equity in same quarter we fill the same values

# %%
def fill_values_in_same_quarter(Series):
    n = len(Series)
    Series = list(Series)  # Transform into list will be faster
    for i in range(1,n):
        if np.isnan(Series[i]):
            if np.isnan(Series[i-1]) == False:
                Series[i] = Series[i-1]
            elif np.isnan(Series[i-2]) == False:
                Series[i] = Series[i-2]
    Series = pd.Series(Series)  # Go back to pd.Series so that can add into dataframe           
    return Series

# %%
# We have to first break index and transform them into columns
df.reset_index(inplace=True)

# %%
df['Total Assets'] = fill_values_in_same_quarter(df['Total Assets'])
df['Stockholders Equity'] = fill_values_in_same_quarter(df['Stockholders Equity'])

# %%
df
# Out:
#        Ticker    Date              Company Name     Cusip     Price    Return  \
# 0           A  200001  AGILENT TECHNOLOGIES INC  00846U10   66.1875 -0.143897
# 1           A  200002  AGILENT TECHNOLOGIES INC  00846U10  103.8750  0.569405
# 2           A  200003  AGILENT TECHNOLOGIES INC  00846U10  104.0000  0.001203
# 3           A  200004  AGILENT TECHNOLOGIES INC  00846U10   88.6250 -0.147837
# 4           A  200005  AGILENT TECHNOLOGIES INC  00846U10   73.6250 -0.169252
# ...       ...     ...                       ...       ...       ...       ...
# 338749     ZZ  201008                SEALY CORP  81213930    2.3700 -0.135037
# 338750     ZZ  201009                SEALY CORP  81213930    2.4400  0.029536
# 338751     ZZ  201010                SEALY CORP  81213930    2.6300  0.077869
# 338752     ZZ  201011                SEALY CORP  81213930    3.0200  0.148289
# 338753     ZZ  201012                SEALY CORP  81213930    2.9200 -0.033113
#
#         Shares Outstanding  Total Assets  Stockholders Equity
# 0                 452000.0      7107.000                  NaN
# 1                 452000.0      7107.000                  NaN
# 2                 452000.0      7107.000                  NaN
# 3                 452000.0      7321.000                  NaN
# 4                 452000.0      7321.000                  NaN
# ...                    ...           ...                  ...
# 338749             97520.0       964.883              -95.431
# 338750             97494.0       964.883              -95.431
# 338751             97494.0       964.883              -95.431
# 338752             97494.0       936.757              -87.639
# 338753             97494.0       936.757              -87.639
#
# [338754 rows x 9 columns]

# %% [markdown]
# # Calculation

# %% [markdown]
# ## Objected Oriented Style - Define Class and functions

# %%
class Solve():
    def __init__(self, df):
        self.df = df
        self.df1 = None
        self.df2 = None
        self.Equal_Weighted_Return = None
        self.Value_Weighted_Return = None
        self.Cumulative_equal_weighted_return = None
        self.Cumulative_value_weighted_return = None
        
    def Calculate_book_to_equity(self):
        self.df['Book to Equity'] = df['Total Assets'] / df['Stockholders Equity']
        
    def Build_new_df(self):
        self.df1 = self.df.copy()
        
        # Calculate each stock's market value
        self.df1['Market Value'] = self.df1['Price'] * self.df1['Shares Outstanding']
        self.df2 = self.df1.copy()
        
        # Delete useless columns
        del self.df1['Total Assets']
        del self.df1['Stockholders Equity']
        del self.df1['Cusip']
        del self.df1['Company Name']
        
        del self.df2['Cusip']
        del self.df2['Date']
        del self.df2['Company Name']
        
    def Show_dataframe(self, option):
        if option == 0:
            return self.df.head()
        elif option == 1:
            return self.df1.head()
        elif option == 2:
            return self.df2.head()
               
    def Show_summary_statistics_times(self):
        pd.set_option('display.max_columns', None)
        self.df1 = self.df.copy()
        return self.df1.groupby('Date').describe(percentiles = [.5])
           
    def Show_summary_statistics_stocks(self):
        pd.set_option('display.max_columns', None)
        return self.df2.groupby('Ticker').describe(percentiles = [.5])
    
    def Calculate_equal_weighted_return(self):
        self.Equal_Weighted_Return = self.df.groupby(['Date'])['Return'].mean()
        
    def Calculate_value_weighted_return(self):        
        # Set 'Date' as index, in order to match
        self.df1.set_index('Date', inplace = True)   
        
        # Calculate Total Market Value
        MktValue = self.df1.groupby('Date')['Market Value'].sum()   
        MktValue = MktValue.to_frame()
        MktValue.rename(columns={'Market Value': 'NYSE Total Value'}, inplace = True)
        
        # Add Total Market Value into dataframe
        self.df1 = pd.merge(self.df1, MktValue, on = 'Date')
        
        # Calculate each stock's weight
        self.df1['Weight'] = self.df1['Market Value'] / self.df1['NYSE Total Value']
        self.df1['Weighted Return'] = self.df1['Weight'] * self.df1['Return']
        
        self.Value_Weighted_Return = self.df1['Weighted Return'].groupby(['Date']).sum()
        
    def Calculate_cumulative_weighted_return(self):
        self.Cumulative_equal_weighted_return = self.Equal_Weighted_Return.cumsum()
        self.Cumulative_value_weighted_return = self.Value_Weighted_Return.cumsum()
        
    def Plot_hist_equal_return(self):
        plt.hist(self.Equal_Weighted_Return, color='orange')
        self.Equal_Weighted_Return.plot(kind = 'hist', color = 'orange', edgecolor = 'black', label = 'histogram')
        self.Equal_Weighted_Return.plot(kind = 'kde', color = 'red', label = 'Kernel Density')
        plt.xlabel('Equal Weighted Monthly Return')
        plt.ylabel('Frequency')
        plt.legend()
        plt.show()
        
    def Plot_hist_value_return(self):
        #plt.hist(self.Value_Weighted_Return, color='orange')
        self.Value_Weighted_Return.plot(kind = 'hist', color = 'orange', edgecolor = 'black', label = 'histogram')
        self.Value_Weighted_Return.plot(kind = 'kde', color = 'red', label = 'Kernel Density')
        plt.xlabel('Value Weighted Monthly Return')
        plt.ylabel('Frequency')
        plt.legend()
        plt.show()
        
    def Compare_two_time_series(self):
        plt.figure(figsize=(16,10))

        plt.plot(self.Cumulative_equal_weighted_return, color = 'purple')
        plt.plot(self.Cumulative_value_weighted_return, color = 'gold')

        font1 = {'family' : 'Times New Roman',
                'weight' : 'normal',
                'size'   : 23}
        plt.legend(['Equal-Weighted Return', 'Value-Weighted Return'], fontsize = 'x-large')

        plt.xlabel('Time', font1)
        plt.ylabel('Cumulative NYSE Monthly Return', font1)
        plt.show()

# %% [markdown]
# ## Create object and do calculations

# %%
Object = Solve(df)

Object.Calculate_book_to_equity()
Object.Build_new_df()
Object.Calculate_equal_weighted_return()
Object.Calculate_value_weighted_return()
Object.Calculate_cumulative_weighted_return()

# AAG      9696.000                 5.0  3236.000000     0.000000  3236.000
# ...           ...                 ...          ...          ...       ...
# ZNH     16853.333               130.0  1016.591223   674.048356   213.061
# ZNT     16853.333               124.0  4179.137056  1121.840889  1001.431
# ZQK      2411.174               132.0  1044.285000     0.000000  1044.285
# ZTR      2411.174               132.0  1044.285000     0.000000  1044.285
# ZZ       1051.136                56.0   564.935786   580.149731  -230.424
#
#                            Book to Equity                                     \
#              50%       max          count      mean           std        min
# Ticker
# A       2584.500  3236.000           24.0  2.910441  1.834002e-01   2.640820
# AA      3236.000  3236.000          132.0  2.996292  0.000000e+00   2.996292
# AAA     3236.000  3236.000           59.0  2.996292  4.479012e-16   2.996292
# AAC     3236.000  3236.000            3.0  2.996292  5.438960e-16   2.996292
# AAG     3236.000  3236.000            5.0  2.996292  0.000000e+00   2.996292
# ...          ...       ...            ...       ...           ...        ...
# ZNH     1321.936  4577.727          130.0  9.944710  5.407271e+00   0.545173
# ZNT     4577.727  4577.727          124.0  0.740413  7.174488e-01   0.318983
# ZQK     1044.285  1044.285          132.0  2.308923  4.457810e-16   2.308923
# ZTR     1044.285  1044.285          132.0  2.308923  4.457810e-16   2.308923
# ZZ      1044.285  1044.285           56.0 -3.059354  5.089754e+00 -10.966092
#
#                             Market Value                              \
#              50%        max        count          mean           std
# Ticker
# A       2.933154   3.238434        132.0  1.364357e+07  6.768020e+06
# AA      2.996292   2.996292        132.0  2.388516e+07  7.717643e+06
# AAA     2.996292   2.996292         59.0  6.776088e+04  4.359591e+04
# AAC     2.996292   2.996292          3.0  1.906210e+05  6.164364e+03
# AAG     2.996292   2.996292          5.0  6.846206e+05  3.101899e+04
# ...          ...        ...          ...           ...           ...
# ZNH     7.883965  21.079925        130.0  5.908638e+04  5.426682e+04
# ZNT     0.550255   3.681594        124.0  9.839202e+05  4.905179e+05
# ZQK     2.308923   2.308923        132.0  9.421570e+05  5.599365e+05
# ZTR     2.308923   2.308923        132.0  5.014668e+05  8.060118e+04
# ZZ      0.881822   1.006560         56.0  7.027830e+05  5.057554e+05
#
#
#                  min           50%           max
# Ticker
# A       4.882185e+06  1.255579e+07  4.700800e+07
# AA      4.995058e+06  2.595984e+07  3.728423e+07
# AAA     5.654400e+03  4.830720e+04  1.439295e+05
# AAC     1.848938e+05  1.898242e+05  1.971450e+05
# AAG     6.463560e+05  6.858968e+05  7.215049e+05
# ...              ...           ...           ...
# ZNH    -3.437779e+04  3.798846e+04  2.456256e+05
# ZNT     3.601459e+05  8.891639e+05  2.011837e+06
# ZQK     1.601138e+05  8.309737e+05  1.990438e+06
# ZTR     3.483688e+05  4.788531e+05  6.694082e+05
# ZZ      7.344560e+04  5.386134e+05  1.599979e+06
#
# [4182 rows x 42 columns]

# %% [markdown]
# ## Show histogram

# %%
Object.Plot_hist_equal_return()

# %%
Object.Plot_hist_value_return()

# %% [markdown]
# ## Show cumulative monthly return -Time Series

# %%
Object.Compare_two_time_series()
